# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
total_results <- read.csv("ad3_window.csv")

# %%
head(total_results)
# Out:
#   change                   zeros ones zero_ids  one_ids   EUR       AFR
# 1 chr1:103525603:103552876 0     0    NA        NA        NA        NA
# 2 chr1:109235113:109238280 0     0    NA        NA        NA        NA
# 3 chr1:109279459:109281327 0     1    NA        AU4991301 NA        AU4991301
# 4 chr1:11029562:11045765   1     0    AU4963301 NA        AU4963301 NA
# 5 chr1:11037596:11045765   0     1    NA        AU4891301 NA        AU4891301
# 6 chr1:12755603:12776216   0     0    NA        NA        NA        NA
#   n_EUR n_AFR chr start     end
# 1 0     0     1   103525603 103552876
# 2 0     0     1   109235113 109238280
# 3 0     1     1   109279459 109281327
# 4 1     0     1    11029562  11045765
# 5 0     1     1    11037596  11045765
# 6 0     0     1    12755603  12776216

# %%
table(total_results$zeros)
# Out:
#   0   1   2
# 440  22   8

# %%
table(total_results$ones)
# Out:
#   0   1   2   3   4   5   6
# 262 119  52   6  20   5   6

# %%
dim(total_results)
# Out:
# [1] 470  12

# %%
length(unique(total_results$change))
# Out:
# [1] 412
