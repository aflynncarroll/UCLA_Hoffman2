# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
ace_ibd <- read.table("ace_ibd.genome")

# %%
head(ace_ibd)
# Out:
#   V1   V2                            V3   V4                            V5 V6
# 1 FID1 IID1                          FID2 IID2                          RT EZ
# 2 0    702-A-80310.01_702-A-80310.01 0    702-A-80310.02_702-A-80310.02 OT 0
# 3 0    702-A-80310.01_702-A-80310.01 0    702-A-80310.03_702-A-80310.03 OT 0
# 4 0    702-A-80310.01_702-A-80310.01 0    702-A-80310.04_702-A-80310.04 OT 0
# 5 0    702-A-80310.01_702-A-80310.01 0    702-A-80310.05_702-A-80310.05 OT 0
# 6 0    702-A-80310.01_702-A-80310.01 0    702-A-80330.01_702-A-80330.01 OT 0
#   V7     V8     V9     V10    V11 V12      V13    V14
# 1 Z0     Z1     Z2     PI_HAT PHE DST      PPC    RATIO
# 2 0.9192 0.0617 0.0192 0.0500 -1  0.643202 0.7195 2.0420
# 3 0.0021 0.9440 0.0539 0.5259 -1  0.766361 1.0000 994.0000
# 4 0.0028 0.9606 0.0366 0.5169 -1  0.762006 1.0000 598.4000
# 5 0.0023 0.9390 0.0587 0.5282 -1  0.767524 1.0000 500.0000
# 6 0.8715 0.1205 0.0080 0.0683 -1  0.646421 0.9059 2.0975

# %%
colnames(ace_ibd) <- as.character(unlist(ace_ibd[1, ]))
ace_ibd <- ace_ibd[-1, ]

# %%
head(ace_ibd)
# Out:
#   FID1 IID1                          FID2 IID2                          RT EZ
# 2 0    702-A-80310.01_702-A-80310.01 0    702-A-80310.02_702-A-80310.02 OT 0
# 3 0    702-A-80310.01_702-A-80310.01 0    702-A-80310.03_702-A-80310.03 OT 0
# 4 0    702-A-80310.01_702-A-80310.01 0    702-A-80310.04_702-A-80310.04 OT 0
# 5 0    702-A-80310.01_702-A-80310.01 0    702-A-80310.05_702-A-80310.05 OT 0
# 6 0    702-A-80310.01_702-A-80310.01 0    702-A-80330.01_702-A-80330.01 OT 0
# 7 0    702-A-80310.01_702-A-80310.01 0    702-A-80330.02_702-A-80330.02 OT 0
#   Z0     Z1     Z2     PI_HAT PHE DST      PPC    RATIO
# 2 0.9192 0.0617 0.0192 0.0500 -1  0.643202 0.7195 2.0420
# 3 0.0021 0.9440 0.0539 0.5259 -1  0.766361 1.0000 994.0000
# 4 0.0028 0.9606 0.0366 0.5169 -1  0.762006 1.0000 598.4000
# 5 0.0023 0.9390 0.0587 0.5282 -1  0.767524 1.0000 500.0000
# 6 0.8715 0.1205 0.0080 0.0683 -1  0.646421 0.9059 2.0975
# 7 0.8953 0.1007 0.0039 0.0543 -1  0.642429 0.5572 2.0104
