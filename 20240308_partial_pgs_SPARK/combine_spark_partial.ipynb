# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# Set the directory path containing the files
directory_path <- "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/"
# Initialize an empty data frame to store the results
result <- data.frame()

# %%
# Loop through files from ace_chr1 to ace_chr22
for (chr in 1:22) {
    
#    chr <- 1
  # Construct the file path
  file_path <- paste0(directory_path, "spark_chr", chr, ".sample_pgs.tsv")
  print(file_path)
  # Read the data from the current file
  data <- read.table(file_path, header = TRUE, , sep = "\t")
  
  # Combine the results for each ancestry (ANC1 and ANC2)
  result <- rbind(result, data)
}
# Out:
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr1.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr2.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr3.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr4.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr5.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr6.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr7.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr8.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr9.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr10.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr11.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr12.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr13.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr14.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr15.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr16.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr17.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr18.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr19.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr20.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr21.sample_pgs.tsv"
# [1] "/u/home/a/afcarrol/project-pasaniuc/Projects/20240308_partial_pgs_SPARK/out/spark_chr22.sample_pgs.tsv"

# %%
# Sum the scores across all chromosomes for each individual by ancestry
final_result <- result %>%
  group_by(indiv) %>%
  summarize(
    ANC1_sum = sum(ANC1, na.rm = TRUE),
    ANC2_sum = sum(ANC2, na.rm = TRUE)
  )

# %%
head(final_result)
# Out:
#   indiv               ANC1_sum ANC2_sum
# 1 SF0000003_SP0000003 3.907868 -0.2853318
# 2 SF0000017_SP0000017 8.198534  0.2379463
# 3 SF0000027_SP0000027 5.168605 -0.2409833
# 4 SF0000027_SP0000034 3.571187 -0.1316452
# 5 SF0000027_SP0000051 5.155264  0.3371704
# 6 SF0000027_SP0000063 4.760903 -0.1541414

# %%
mean(final_result$ANC1_sum)
# Out:
# [1] 4.501456

# %%
mean(final_result$ANC2_sum)
# Out:
# [1] 0.1804877

# %%
final_result$total_pgs <- final_result$ANC1_sum+final_result$ANC2_sum

# %%
mean(final_result$total_pgs)
# Out:
# [1] 4.681944

# %%
write_csv(final_result, "spark_anc_part_pgs.csv")
