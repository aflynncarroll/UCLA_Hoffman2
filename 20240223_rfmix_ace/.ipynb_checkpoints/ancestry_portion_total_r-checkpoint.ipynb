# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# Set the directory path containing the files
directory_path <- "/u/project/geschwind/shared/PRS/20240223_ACE_RFMix/"
# Initialize an empty data frame to store the results
result <- data.frame()

# %%
chrom <- 22

test_path <- paste0(directory_path, "chr", chrom, ".rfmix.Q")
print(test_path)
# Out:
# [1] "/u/project/geschwind/shared/PRS/20240223_ACE_RFMix/chr22.rfmix.Q"

# %%
test_data <- read.table(test_path, header = TRUE, , sep = "\t")

# %%
head(test_data)
# Out:
#   AU003305_AU003305   X0.98939 X0.01061
# 1 AU0226302_AU0226302 1.00000  0.00000
# 2 AU0226303_AU0226303 1.00000  0.00000
# 3 AU025304_AU025304   1.00000  0.00000
# 4 AU025804_AU025804   0.98762  0.01238
# 5 MN.308_MN.308       1.00000  0.00000
# 6 AU032904_AU032904   0.93811  0.06189

# %%
# Loop through files from ace_chr1 to ace_chr22
for (chr in 1:22) {
    

  # Construct the file path
  file_path <- paste0(directory_path, "ace_chr", chr, ".sample_pgs.tsv")
  print(file_path)
  # Read the data from the current file
  data <- read.table(file_path, header = TRUE, , sep = "\t")
  
  # Combine the results for each ancestry (ANC1 and ANC2)
  result <- rbind(result, data)
}

# %%
# Sum the scores across all chromosomes for each individual by ancestry
final_result <- result %>%
  group_by(indiv) %>%
  summarize(
    ANC1_sum = sum(ANC1, na.rm = TRUE),
    ANC2_sum = sum(ANC2, na.rm = TRUE)
  )

# %%
write_csv(final_result, "ace_anc_part_pgs.csv")
