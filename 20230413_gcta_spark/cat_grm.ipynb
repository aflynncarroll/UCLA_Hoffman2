# %% [markdown]
# Merge all the gcta files together

# %%
cat test_grm_spark_1000.part_1000_*.grm.id > ../test_grm_spark_1000.grm.id

# %%
cat test_grm_spark_1000.part_1000_*.grm.bin > ../test_grm_spark_1000.grm.bin

# %%
cat test_grm_spark_1000.part_1000_*.grm.N.bin > ../test_grm_spark_1000.grm.N.bin

# %%
ls
# Out:
# cat_grm.ipynb            SPARK_GRM_files.txt
# gcta_filter_sh.ipynb     SPARK_GRM.grm.id
# gcta_results_r.ipynb     SPARK_GRM.log
# gcta_spark_sh.ipynb      test_grm_spark_100000.part_100000_000001.grm.bin
# grm_SPARK_hm3            test_grm_spark_100000.part_100000_000001.grm.id
# joined_SPARK_hm3         test_grm_spark_100000.part_100000_000001.grm.N.bin
# misc                     test_grm_spark_100000.part_100000_000001.log
# related                  test_grm_spark_1000_1000.part_1000_1000.log
# run_gcta_spark_chrom.sh  test_grm_spark_1000.part_1000_0001.grm.id
# run_gcta_spark_hm3.sh    test_grm_spark_1000.part_1000_0001.log
# run_gcta_spark.sh        Untitled.ipynb
# SPARK_GCTA_chrom         untitled.txt

# %%
cat grm_SPARK_hm3/spark_hm3_grm.part_250_*.grm.id > joined_SPARK_hm3/spark_hm3_joined.grm.id

# %%
cat grm_SPARK_hm3/spark_hm3_grm.part_250_*.grm.bin > joined_SPARK_hm3/spark_hm3_joined.grm.bin

# %%
cat grm_SPARK_hm3/spark_hm3_grm.part_250_*.grm.N.bin > joined_SPARK_hm3/spark_hm3_joined.grm.N.bin
