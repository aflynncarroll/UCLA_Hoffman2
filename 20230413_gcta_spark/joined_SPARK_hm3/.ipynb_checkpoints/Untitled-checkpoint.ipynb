# %%
module load anaconda3/2023.03

conda activate gcta
# Out:
# (gcta)
# : 1

# %%
ls
# Out:
# just_anc_part_grm            spark_hm3_joined.grm.id
# partial_score_indv_gcta.txt  spark_hm3_joined.grm.N.bin
# spark_hm3_joined.grm.bin     Untitled.ipynb
# (gcta)
# : 1

# %%
gcta64 --grm spark_hm3_joined --keep partial_score_indv_gcta.txt --make-grm --out just_anc_part_grm/ancpar_subset_grm
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 11:33:00 PDT on Mon May 01 2023.
# Hostname: n7124
#
# Accepted options:
# --grm spark_hm3_joined
# --keep partial_score_indv_gcta.txt
# --make-grm
# --out just_anc_part_grm/ancpar_subset_grm
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [spark_hm3_joined.grm.id].
# 69487 IDs are read from [spark_hm3_joined.grm.id].
# Reading the GRM from [spark_hm3_joined.grm.bin].
