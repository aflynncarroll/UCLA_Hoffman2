# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3/2023.03

conda activate gcta
# Out:
# (gcta)
# : 1

# %%
    gcta64 \
    --thread-num 4 \
    --grm joined_SPARK_hm3/spark_hm3_joined \
    --make-grm-gz \
    --out comp_text_grm/spark_hm3_joined
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 17:35:31 PDT on Tue Apr 25 2023.
# Hostname: n7124
#
# Accepted options:
# --thread-num 4
# --grm joined_SPARK_hm3/spark_hm3_joined
# --make-grm-gz
# --out related/spark_hm3_joined
#
# Note: the program will be running on 4 threads.
#
# Reading IDs of the GRM from [joined_SPARK_hm3/spark_hm3_joined.grm.id].
# 69487 IDs are read from [joined_SPARK_hm3/spark_hm3_joined.grm.id].
# Reading the GRM from [joined_SPARK_hm3/spark_hm3_joined.grm.bin].
# Reading the number of SNPs for the GRM from [joined_SPARK_hm3/spark_hm3_joined.grm.N.bin].
# ...

# %%
pwd
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20230413_gcta_spark
# (gcta)
# : 1

# %%
gcta64 --bfile related/spark_hm3_joined --make-grm --grm-cutoff 0.05 --out mygrm --keep myrelated.txt

# %%
    gcta64 \
    --thread-num 1 \
    --mgrm SPARK_GRM_files.txt \
    --make-grm-gz \
    --out related/combined_grm
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 16:19:45 PDT on Mon Apr 24 2023.
# Hostname: n7124
#
# Accepted options:
# --thread-num 1
# --mgrm SPARK_GRM_files.txt
# --make-grm-gz
# --out related/readable_grm
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# There are 22 GRM file names specified in [SPARK_GRM_files.txt].
# 69487 individuals in common in the GRM files.
# terminate called after throwing an instance of 'std::bad_alloc'
#   what():  std::bad_alloc
# Aborted
# (gcta)
# : 1

# %%
    gcta64 \
    --thread-num 1 \
    --mgrm SPARK_GRM_files.txt \
    --make-grm \
    --out related/combined_grm

# %%
    gcta64 \
    --thread-num 8 \
    --grm test_grm_spark_1000 \
    --make-grm-gz \
    --out related/readable_grm
   # --grm-cutoff 0.05 \
    #--keep \
#4:11
gcta --mgrm <GRM files> --make-grm --out <output filename>
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 17:35:27 PDT on Wed Apr 19 2023.
# Hostname: n7124
#
# Accepted options:
# --thread-num 8
# --grm test_grm_spark_1000
# --make-grm-gz
# --out related/readable_grm
#
# Note: the program will be running on 8 threads.
#
# Reading IDs of the GRM from [test_grm_spark_1000.grm.id].
# 69458 IDs are read from [test_grm_spark_1000.grm.id].
# Reading the GRM from [test_grm_spark_1000.grm.bin].
# Error: Is the size of the [test_grm_spark_1000.grm.bin] file incorrect?
# An error occurs, please check the options or data
# (gcta) (gcta) (gcta)
# : 1

# %%
    gcta64 \
    --grm test_grm_spark_1000 \
    --make-grm-gz \
    --out related/readable_grm_3
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 19:44:27 PDT on Wed Apr 19 2023.
# Hostname: n6119
#
# Accepted options:
# --grm test_grm_spark_1000
# --make-grm-gz
# --out related/readable_grm_3
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [test_grm_spark_1000.grm.id].
# 69458 IDs are read from [test_grm_spark_1000.grm.id].
# Reading the GRM from [test_grm_spark_1000.grm.bin].
# Error: Is the size of the [test_grm_spark_1000.grm.bin] file incorrect?
# ...

# %%
gcta64 \
--grm test_grm_spark_1000 \
--grm-cutoff 0.05 \
--out related/readable_grm_2
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 19:57:40 PDT on Wed Apr 19 2023.
# Hostname: n6119
#
# Accepted options:
# --grm test_grm_spark_1000
# --grm-cutoff1
# --out related/readable_grm_2
#
#
#
# Analysis finished at 19:57:40 PDT on Wed Apr 19 2023
# Overall computational time: 0.00 sec.
# (gcta)
# : 1

# %%
pwd
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20230413_gcta_spark
