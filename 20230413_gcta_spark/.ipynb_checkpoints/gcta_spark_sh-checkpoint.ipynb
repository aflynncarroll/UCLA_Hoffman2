# %% [markdown]
# # Do GRM (Genetic Relationship Matrix) for SPARK Data

# %%
module load anaconda3/2023.03

conda activate gcta
#enviro with gcta installed
# Out:
# (gcta) (gcta) (gcta) (gcta)
# : 1

# %%
pwd
#11:52
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20230413_gcta_spark
# (gcta)
# : 1

# %%
gcta --bfile /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 --make-grm --out SPARK_GRM
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 11:52:12 PDT on Thu Apr 13 2023.
# Hostname: n6116
#
# Options:
#
# --bfile /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6
# --make-grm
# --out SPARK_GRM
#
# Note: GRM is computed using the SNPs on the autosomes.
# Reading PLINK FAM file from [/u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6.fam]...
# 69487 individuals to be included from FAM file.
# ...

# %%
time gcta64 --bfile /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 --make-grm-part 100000 1 --thread-num 1 --out test_grm_spark_100000
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 12:31:57 PDT on Thu Apr 13 2023.
# Hostname: n6116
#
# Options:
#
# --bfile /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6
# --make-grm-part 100000 1
# --thread-num 1
# --out test_grm_spark_100000
#
# The program will be running with up to 1 threads.
# Note: GRM is computed using the SNPs on the autosomes.
# ...

# %%
time echo "tree"
# Out:
# tree
#
# real	0m0.000s
# user	0m0.000s
# sys	0m0.000s
# (gcta)
# : 1
