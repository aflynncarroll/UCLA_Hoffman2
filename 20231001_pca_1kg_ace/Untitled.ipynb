# %%
library(bigsnpr)
library(ggplot2)
library(readr)
library(dplyr)
# Out:
# Error in library(bigsnpr): there is no package called ‘bigsnpr’
# Traceback:
#
# 1. library(bigsnpr)

# %%
install.package("bigsnpr")
# Out:
# Error in install.package("bigsnpr"): could not find function "install.package"
# Traceback:
