# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# old-home-afcarrol/afcarrol/project-pasaniuc/Projects/20230906_imputed_data_qc/unzip_combine.ipynb

# %%
ex_2011_158_230815 <- read.table("/u/project/pasaniuc/afcarrol/Projects/20230906_imputed_data_qc/ex_2011_158_230815.txt")

# %%
ex_2011_158_230815$V2 <- gsub("_(.*)", "", ex_2011_158_230815$V1)
ex_2011_158_230815$file <- "2011_158_230815"

# %%
clean101007_total <- read.table("/u/project/pasaniuc/afcarrol/Projects/20230906_imputed_data_qc/ex_2010_002_101007.txt")

# %%
clean101007_total$V2 <- gsub("_(.*)", "", clean101007_total$V1)
clean101007_total$file <- "2010_002_101007"

# %%
clean181212 <- read.table("/u/project/pasaniuc/afcarrol/Projects/20230906_imputed_data_qc/ex_2017_9154_181212.txt")

# %%
clean181212$V2 <- gsub("_(.*)", "", clean181212$V1)
clean181212$file <- "2017_9154_181212"

# %%
merge_clean190118 <- read.table("//u/project/pasaniuc/afcarrol/Projects/20230906_imputed_data_qc/ex_2017_9154_190118.txt")

# %%
merge_clean190118$V2 <- gsub("_(.*)", "", merge_clean190118$V1)
merge_clean190118$file <- "2017_9154_190118"

# %%
total_removed <- rbind(ex_2011_158_230815, clean101007_total, clean181212, merge_clean190118)

# %%
write_csv(total_removed, "ace_removed.csv")

# %%
total_removed
# Out:
#     V1                              V2              file
# 1   AU1920201_AU1920201             AU1920201       2011_158_230815
# 2   AU1920202_AU1920202             AU1920202       2011_158_230815
# 3   AU1920302_AU1920302             AU1920302       2011_158_230815
# 4   AU1920303_AU1920303             AU1920303       2011_158_230815
# 5   AU2911201_AU2911201             AU2911201       2011_158_230815
# 6   AU2911202_AU2911202             AU2911202       2011_158_230815
# 7   AU3026301_AU3026301             AU3026301       2011_158_230815
# 8   AU3026202_AU3026202             AU3026202       2011_158_230815
# 9   AU3026201_AU3026201             AU3026201       2011_158_230815
# 10  AU3299201_AU3299201             AU3299201       2011_158_230815
# 11  AU3459202_AU3459202             AU3459202       2011_158_230815
# 12  AU3459301_AU3459301             AU3459301       2011_158_230815
# 13  AU3299301_AU3299301             AU3299301       2011_158_230815
# ...
