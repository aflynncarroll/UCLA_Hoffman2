# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
/u/project/geschwind/davidgib/ace/spark_ace_pgs_noPar.txt

# %%
ace_snps <- read.table('/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/merged_output_2_var.txt')

# %%
head(ace_snps)
# Out:
#   V1    V2    V3                V4  V5
# 1 chr10 12040 chr10:12040:G:A   G   A
# 2 chr10 14470 chr10:14470:C:T   C   T
# 3 chr10 31093 chr10:31093:GAC:G GAC G
# 4 chr10 36953 chr10:36953:G:C   G   C
# 5 chr10 37005 chr10:37005:C:A   C   A
# 6 chr10 40467 chr10:40467:A:C   A   C

# %%
dim(ace_snps)
# Out:
# [1] 55254922        5
