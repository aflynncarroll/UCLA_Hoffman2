# %%
module load anaconda3/2023.03

# %%
conda activate plink2_env
# Out:
# (plink2_env)
# : 1

# %%
module load bcftools

# %%
plink2
# Out:
# PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
#
#   plink2 <input flag(s)...> [command flag(s)...] [other flag(s)...]
#   plink2 --help [flag name(s)...]
#
# Commands include --rm-dup list, --make-bpgen, --export, --freq, --geno-counts,
# --sample-counts, --missing, --hardy, --indep-pairwise, --ld, --sample-diff,
# --make-king, --king-cutoff, --write-samples, --write-snplist, --make-grm-list,
# --pca, --glm, --adjust-file, --score, --variant-score, --genotyping-rate,
# --pgen-info, --validate, and --zst-decompress.
#
# "plink2 --help | more" describes all functions.
# (plink2_env)
# : 1

# %%
zcat /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/merged_output_2.vcf.gz  | \
bcftools query -f '%CHROM\t%POS\t%ID\t%REF\t%ALT\n' > /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/merged_output_2_var.txt

# %%
ls -lh /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined_hm3_filtered/
# Out:
# total 0
# (plink2_env)
# : 1

# %%
zgrep -E '^[^#]' /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/merged_output_2.vcf.gz | \
    cut -f 3 > /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/merged_variant_list.txt

# %%
# qrsh -l h_data=100G,h_rt=48:00:00
# plink2 command ran in like 28m

# %%
qsub /u/project/pasaniuc/afcarrol/Projects/20230906_imputed_data_qc/ace_subset_hm3.sh

# %%
time plink2 --vcf /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/merged_output_2.vcf.gz \
       --extract /u/project/pasaniuc/afcarrol/Projects/20230906_imputed_data_qc/hm3_filtered_snps_ace.txt \
       --make-bed \
       --out /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined_hm3_filtered/merged_hm3

# %%
plink --vcf /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/merged_output_2.vcf.gz \
--extract /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/hm3_snp_pos.txt \
--make-bed \
--out /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined_hm3_filtered/merged_hm3

# %%
ls

# %%
ls /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/
# Out:
# 1k_ref_bed                    merge_2.txt    SPARK_20210118
# combined_bfile                merge_ref.txt  SPARK_bed_by_chrom
# files_for_pca.ipynb           merge.txt      SPARK_full_hampap3
# find_union_bed.ipynb          misc           split_spark_chr.ipynb
# hapmap3_var_extract_py.ipynb  plink.ipynb    split_spark_chrom.sh
# hm3_snp_pos.txt               plink.log      subset_SPARK_hapmap3.ipynb
# list.snps                     plink.nosex    Untitled1.ipynb
# map.rds                       REF_1KG        Untitled.ipynb

# %%
ls /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined
# Out:
# merged_output_2.vcf.gz      merged_output.vcf.gz
# merged_output_2.vcf.gz.csi  samples_by_file.csv

# %%
mkdir /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined_hm3_filtered

# %%
ls /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/
# Out:
# 2010-002.clean101007_total_ex.vcf.gz
# 2010-002.clean101007_total_ex.vcf.gz.csi
# 2011-158.clean230815_ex.vcf.gz
# 2011-158.clean230815_ex.vcf.gz.csi
# 2013-111A.ATN.clean170906.vcf.gz
# 2013-111A.ATN.clean170906.vcf.gz.csi
# 2013-438.clean230817.vcf.gz
# 2013-438.clean230817.vcf.gz.csi
# 2015-9017.clean170906.vcf.gz
# 2015-9017.clean170906.vcf.gz.csi
# 2016-9174-3_clean190123.vcf.gz
# 2016-9174-3_clean190123.vcf.gz.csi
# 2016-9174_clean190123.vcf.gz
# 2016-9174_clean190123.vcf.gz.csi
# 2017-9154-merge_clean181212_ex.vcf.gz
# 2017-9154-merge_clean181212_ex.vcf.gz.csi
# 2017-9154_merge_clean190118_ex.vcf.gz
# 2017-9154_merge_clean190118_ex.vcf.gz.csi
# 2020-9133.clean201112.vcf.gz
# 2020-9133.clean201112.vcf.gz.csi
# 2022-9163.clean230801.vcf.gz
# 2022-9163.clean230801.vcf.gz.csi
# combined
# combined_hm3_filtered
# old_full_vcfs
