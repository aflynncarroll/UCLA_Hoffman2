# %%
wget http://resource.psychencode.org/Datasets/Derived/QTLs/Full_hg19_cis-eQTL.txt.gz
# Out:
# --2024-10-15 08:43:31--  http://resource.psychencode.org/Datasets/Derived/QTLs/Full_hg19_cis-eQTL.txt.gz
# Resolving resource.psychencode.org (resource.psychencode.org)... 52.72.81.43
# Connecting to resource.psychencode.org (resource.psychencode.org)|52.72.81.43|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3293218507 (3.1G) [application/x-gzip]
# Saving to: ‘Full_hg19_cis-eQTL.txt.gz’
#
# 100%[====================================>] 3,293,218,507 24.7MB/s   in 90s
#
# 2024-10-15 08:45:04 (34.9 MB/s) - ‘Full_hg19_cis-eQTL.txt.gz’ saved [3293218507/3293218507]

# %%
wget  http://resource.psychencode.org/Datasets/Derived/QTLs/DER-08a_hg38_eQTL.significant.txt
# Out:
# --2024-10-22 11:01:40--  http://resource.psychencode.org/Datasets/Derived/QTLs/DER-08a_hg38_eQTL.significant.txt
# Resolving resource.psychencode.org (resource.psychencode.org)... 52.72.81.43
# Connecting to resource.psychencode.org (resource.psychencode.org)|52.72.81.43|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 376136363 (359M) [text/plain]
# Saving to: ‘DER-08a_hg38_eQTL.significant.txt’
#
# 100%[======================================>] 376,136,363 9.47MB/s   in 46s
#
# 2024-10-22 11:02:32 (7.86 MB/s) - ‘DER-08a_hg38_eQTL.significant.txt’ saved [376136363/376136363]

# %%
ls
# Out:
# DER-08a_hg38_eQTL.significant.txt  Full_hg19_cis-eQTL.txt
# explore_eqtl_data_r.ipynb          get_eqtl_data_sh.ipynb

# %%
gunzip Full_hg19_cis-eQTL.txt.gz

# %%
ls -lh
# Out:
# total 17G
# -rw-r--r--. 1 aflynnca pasaniuc  17G Jan 10  2020 Full_hg19_cis-eQTL.txt
# -rw-r--r--. 1 aflynnca pasaniuc 2.0K Oct 15 08:47 get_eqtl_data_sh.ipynb

# %%
head Full_hg19_cis-eQTL.txt
# Out:
# ENSG00000215004.3 chr3 29128887 29128887 + 4558 -998415 3:28130472 chr3 28130472 28130472 0.935933 0.00173423 0
# ENSG00000215004.3 chr3 29128887 29128887 + 4558 -998201 3:28130686 chr3 28130686 28130686 0.934622 0.00183973 0
# ENSG00000215004.3 chr3 29128887 29128887 + 4558 -996771 3:28132116 chr3 28132116 28132116 0.445269 0.0164145 0
# ENSG00000215004.3 chr3 29128887 29128887 + 4558 -996343 3:28132544 chr3 28132544 28132544 0.351889 -0.0504872 0
# ENSG00000215004.3 chr3 29128887 29128887 + 4558 -996026 3:28132861 chr3 28132861 28132861 0.116941 0.0683104 0
# ENSG00000215004.3 chr3 29128887 29128887 + 4558 -995791 3:28133096 chr3 28133096 28133096 0.582236 0.0120821 0
# ENSG00000215004.3 chr3 29128887 29128887 + 4558 -993903 3:28134984 chr3 28134984 28134984 0.513291 0.0141408 0
# ENSG00000215004.3 chr3 29128887 29128887 + 4558 -992088 3:28136799 chr3 28136799 28136799 0.596497 0.0115405 0
# ...

# %%
pwd
# Out:
# /u/project/pasaniuc/aflynnca/projects/20241015_asd_pgs/20241015_brain_eqtl_data
