# %%
wget https://ftp.ebi.ac.uk/pub/databases/spot/pgs/scores/PGS000327/ScoringFiles/PGS000327.txt.gz
# Out:
# --2024-10-24 15:04:24--  https://ftp.ebi.ac.uk/pub/databases/spot/pgs/scores/PGS000327/ScoringFiles/PGS000327.txt.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 308162 (301K) [application/x-gzip]
# Saving to: ‘PGS000327.txt.gz’
#
# 100%[======================================>] 308,162      536KB/s   in 0.6s
#
# 2024-10-24 15:04:25 (536 KB/s) - ‘PGS000327.txt.gz’ saved [308162/308162]

# %%
ls
# Out:
# get_asd_pgs_sh.ipynb  PGS000327.txt.gz

# %%
gunzip PGS000327.txt.gz

# %%
ls -lh
# Out:
# total 984K
# -rw-r--r--. 1 aflynnca pasaniuc   72 Oct 24 15:03 get_asd_pgs_sh.ipynb
# -rw-r--r--. 1 aflynnca pasaniuc 976K Dec 15  2021 PGS000327.txt

# %%
wget https://ftp.ebi.ac.uk/pub/databases/spot/pgs/scores/PGS000327/ScoringFiles/Harmonized/PGS000327_hmPOS_GRCh38.txt.gz
# Out:
# --2024-10-24 15:08:02--  https://ftp.ebi.ac.uk/pub/databases/spot/pgs/scores/PGS000327/ScoringFiles/Harmonized/PGS000327_hmPOS_GRCh38.txt.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 514072 (502K) [application/x-gzip]
# Saving to: ‘PGS000327_hmPOS_GRCh38.txt.gz’
#
# 100%[======================================>] 514,072      741KB/s   in 0.7s
#
# 2024-10-24 15:08:03 (741 KB/s) - ‘PGS000327_hmPOS_GRCh38.txt.gz’ saved [514072/514072]

# %%
ls
# Out:
# get_asd_pgs_sh.ipynb  PGS000327_hmPOS_GRCh38.txt.gz  PGS000327.txt

# %%
gunzip PGS000327_hmPOS_GRCh38.txt.gz

# %%
ls -lh
# Out:
# total 2.7M
# -rw-r--r--. 1 aflynnca pasaniuc 2.2K Oct 24 15:05 get_asd_pgs_sh.ipynb
# -rw-r--r--. 1 aflynnca pasaniuc 1.8M Jul 29  2022 PGS000327_hmPOS_GRCh38.txt
# -rw-r--r--. 1 aflynnca pasaniuc 976K Dec 15  2021 PGS000327.txt

# %%
# Out:
# bash: conda: command not found
# : 127
