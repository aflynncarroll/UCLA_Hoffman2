# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3
# Out:
# . /u/local/Modules/default/init/modules.sh
# (plink2_run) module load anaconda3
# (plink2_run)
# : 1

# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3
conda activate plink2_env
module load java/jdk-11.0.14
# Out:
# EnvironmentNameNotFound: Could not find conda environment: plink2_env
# You can list all discoverable environments with `conda info --envs`.

# %%
java -version
# Out:
# java -version
# java version "11.0.14" 2022-01-18 LTS
# Java(TM) SE Runtime Environment 18.9 (build 11.0.14+8-LTS-263)
# Java HotSpot(TM) 64-Bit Server VM 18.9 (build 11.0.14+8-LTS-263, mixed mode)
# (plink2_run)
# : 1

# %%
curl -fsSL get.nextflow.io | bash
# Out:
# curl -fsSL get.nextflow.io | bash
# ^Cwnloading nextflow dependencies. It may require a few seconds, please wait ..
# (plink2_run)

# %%
nextflow run pgscatalog/pgsc_calc -profile test,singularity
# Out:
# gularity run pgscatalog/pgsc_calc -profile test,sin
# bash: nextflow: command not found
# (plink2_run)
# : 1

# %%
nextflow -version
# Out:
# nextflow -version
# bash: nextflow: command not found
# (plink2_run)
# : 1

# %%
conda activate plink2_run
# Out:
# conda activate plink2_run
# (plink2_run)
# : 1

# %%
conda info --envs
# Out:
# # conda environments:
# #
# plink2_run               /u/home/a/aflynnca/.conda/envs/plink2_run
# base                     /u/local/apps/anaconda3/2020.11
# ClearMap2                /u/local/apps/anaconda3/2020.11/envs/ClearMap2
# DLC-CPU                  /u/local/apps/anaconda3/2020.11/envs/DLC-CPU
# DLC-GPU                  /u/local/apps/anaconda3/2020.11/envs/DLC-GPU
# HiC-Pro_v3.1.0           /u/local/apps/anaconda3/2020.11/envs/HiC-Pro_v3.1.0
# biobakery                /u/local/apps/anaconda3/2020.11/envs/biobakery
# biobakery3               /u/local/apps/anaconda3/2020.11/envs/biobakery3
# bwa-mem2                 /u/local/apps/anaconda3/2020.11/envs/bwa-mem2
# canu                     /u/local/apps/anaconda3/2020.11/envs/canu
# charlietest              /u/local/apps/anaconda3/2020.11/envs/charlietest
# cutadaptenv              /u/local/apps/anaconda3/2020.11/envs/cutadaptenv
# deeptools                /u/local/apps/anaconda3/2020.11/envs/deeptools
# ensembl-vep              /u/local/apps/anaconda3/2020.11/envs/ensembl-vep
# goatools                 /u/local/apps/anaconda3/2020.11/envs/goatools
# ipyrad                   /u/local/apps/anaconda3/2020.11/envs/ipyrad
# matlab_r2020a            /u/local/apps/anaconda3/2020.11/envs/matlab_r2020a
# midas                    /u/local/apps/anaconda3/2020.11/envs/midas
# multiqc                  /u/local/apps/anaconda3/2020.11/envs/multiqc
# ncl_6.6.2                /u/local/apps/anaconda3/2020.11/envs/ncl_6.6.2
# nextflow                 /u/local/apps/anaconda3/2020.11/envs/nextflow
# octopus                  /u/local/apps/anaconda3/2020.11/envs/octopus
# orthofinderenv           /u/local/apps/anaconda3/2020.11/envs/orthofinderenv
# pegasus                  /u/local/apps/anaconda3/2020.11/envs/pegasus
# phyluce-1.7.1            /u/local/apps/anaconda3/2020.11/envs/phyluce-1.7.1
# pytorch-1.9.0-cpu        /u/local/apps/anaconda3/2020.11/envs/pytorch-1.9.0-cpu
# pytorch-1.9.0-gpu        /u/local/apps/anaconda3/2020.11/envs/pytorch-1.9.0-gpu
# pytorchtest              /u/local/apps/anaconda3/2020.11/envs/pytorchtest
# r-monocle3               /u/local/apps/anaconda3/2020.11/envs/r-monocle3
# rmats                    /u/local/apps/anaconda3/2020.11/envs/rmats
# sklearn                  /u/local/apps/anaconda3/2020.11/envs/sklearn
# snakemake                /u/local/apps/anaconda3/2020.11/envs/snakemake
# suite2p                  /u/local/apps/anaconda3/2020.11/envs/suite2p
# tensorflow_cpu           /u/local/apps/anaconda3/2020.11/envs/tensorflow_cpu
# test2                    /u/local/apps/anaconda3/2020.11/envs/test2
# testpython               /u/local/apps/anaconda3/2020.11/envs/testpython
# tf2-cpu                  /u/local/apps/anaconda3/2020.11/envs/tf2-cpu
# tf2-gpu                  /u/local/apps/anaconda3/2020.11/envs/tf2-gpu
# treemix                  /u/local/apps/anaconda3/2020.11/envs/treemix

# %%
module load java/jdk-11.0.14
# Out:
# module load java/jdk-11.0.14
# (plink2_run)
# : 1

# %%
ls /u/project/pasaniuc/afcarrol/Projects/20221020_pgsc_calc_autism/
# Out:
# autism_pgs.ipynb  chr1_test.csv      PGS000327.txt.gz  SPARK_full.csv
# chr1_test_2.csv   chr1_test_vcf.csv  results           work
# (plink2_run)
# : 1

# %%
ls
# Out:
# get_asd_pgs_sh.ipynb        PGS000327.txt
# PGS000327_hmPOS_GRCh38.txt  run_pgs_on_local_sh.ipynb
# (plink2_run)
# : 1

# %%
pwd
# Out:
# /u/project/pasaniuc/aflynnca/projects/20241015_asd_pgs/20241024_asd_pgs
# (plink2_run)
# : 1

# %%
/u/project/pasaniuc/afcarrol/Projects/20221017_pgsc_calc_test/nextflow run pgscatalog/pgsc_calc -r v1.2.0 \
    -profile conda \
    --input /u/project/pasaniuc/afcarrol/Projects/20221020_pgsc_calc_autism/SPARK_full.csv --target_build GRCh38 \
    --scorefile /u/project/pasaniuc/aflynnca/projects/20241015_asd_pgs/20241024_asd_pgs/PGS000327_hmPOS_GRCh38.txt \
    --min_overlap 0.001
# Out:
# _calc_test/nextflow run pgscatalog/pgsc_calc -r v1.2.0 \
#     -profile conda \
# calc_autism/SPARK_full.csv --target_build GRCh38 \20221020_pgsc_
# sd_pgs/20241024_asd_pgs/PGS000327_hmPOS_GRCh38.txt \s/20241015_a
#     --min_overlap 0.001
# N E X T F L O W  ~  version 22.10.1
# Launching `https://github.com/pgscatalog/pgsc_calc` [shrivelled_shaw] DSL2 - revision: 7e11510b93 [v1.2.0]
#
#
# ------------------------------------------------------
#   pgscatalog/pgsc_calc v1.2.0
# ------------------------------------------------------
# Core Nextflow options
#   revision    : v1.2.0
#   runName     : shrivelled_shaw
#   launchDir   : /u/project/pasaniuc/aflynnca/projects/20241015_asd_pgs/20241024_asd_pgs
#   workDir     : /u/project/pasaniuc/aflynnca/projects/20241015_asd_pgs/20241024_asd_pgs/work
#   projectDir  : /u/home/a/aflynnca/.nextflow/assets/pgscatalog/pgsc_calc
#   userName    : aflynnca
#   profile     : conda
#   configFiles : /u/home/a/aflynnca/.nextflow/assets/pgscatalog/pgsc_calc/nextflow.config
#
# Input/output options
#   input       : /u/project/pasaniuc/afcarrol/Projects/20221020_pgsc_calc_autism/SPARK_full.csv
#   scorefile   : /u/project/pasaniuc/aflynnca/projects/20241015_asd_pgs/20241024_asd_pgs/PGS000327_hmPOS_GRCh38.txt
#   pgs_id      : null
#   pgp_id      : null
#   trait_efo   : null
#   target_build: GRCh38
#
# Variant Matching QC & Filtering
#   min_overlap : 0.001
#
# Institutional config options
#   hostnames   : [:]
#
# Max job request options
#   max_cpus    : 2
#   max_memory  : 16.GB
#
# Generic options
#   enable_conda: true
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use pgscatalog/pgsc_calc for your analysis please cite:
#
# * The Polygenic Score Catalog
#   https://doi.org/10.1038/s41588-021-00783-5
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/pgscatalog/pgsc_calc/blob/master/CITATIONS.md
# ------------------------------------------------------
# WARN: ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   There is a problem with your Conda configuration!
#
#   You will need to set-up the conda-forge and bioconda channels correctly.
#   Please refer to https://bioconda.github.io/user/install.html#set-up-channels
#   NB: The order of the channels matters!
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (1)
# [9c/ce6df6] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (1)
# [9c/ce6df6] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# Error executing process > 'PGSCATALOG_PGSCALC:PGSCALC:INPUT_CHECK:SAMPLESHEET_JSON (SPARK_full.csv)'
#
# Caused by:
#   Process `PGSCATALOG_PGSCALC:PGSCALC:INPUT_CHECK:SAMPLESHEET_JSON (SPARK_full.csv)` terminated with an error exit status (1)
#
# Command executed:
#
#   samplesheet_to_json.py SPARK_full.csv out.json
#
#   cat <<-END_VERSIONS > versions.yml
#   SAMPLESHEET_JSON:
#       python: $(echo $(python --version 2>&1) | cut -f 2 -d ' ')
#   END_VERSIONS
#
# Command exit status:
#   1
#
# Command output:
#   (empty)
#
# Command error:
#   Traceback (most recent call last):
#     File "/u/home/a/aflynnca/.nextflow/assets/pgscatalog/pgsc_calc/bin/samplesheet_to_json.py", line 6, in <module>
#       import pandas as pd
#   ModuleNotFoundError: No module named 'pandas'
#
# Work dir:
#   /u/project/pasaniuc/aflynnca/projects/20241015_asd_pgs/20241024_asd_pgs/work/9c/ce6df62cc3012cc70f7a13eb983d62
#
# Tip: when you have fixed the problem you can continue the execution adding the option `-resume` to the run command line
#
#
#
# executor >  local (1)
# [9c/ce6df6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1, failed: 1 ✘
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# Execution cancelled -- Finishing pending tasks before exit
# Error executing process > 'PGSCATALOG_PGSCALC:PGSCALC:INPUT_CHECK:SAMPLESHEET_JSON (SPARK_full.csv)'
#
# Caused by:
#   Process `PGSCATALOG_PGSCALC:PGSCALC:INPUT_CHECK:SAMPLESHEET_JSON (SPARK_full.csv)` terminated with an error exit status (1)
#
# Command executed:
#
#   samplesheet_to_json.py SPARK_full.csv out.json
#
#   cat <<-END_VERSIONS > versions.yml
#   SAMPLESHEET_JSON:
#       python: $(echo $(python --version 2>&1) | cut -f 2 -d ' ')
#   END_VERSIONS
#
# Command exit status:
#   1
#
# Command output:
#   (empty)
#
# Command error:
#   Traceback (most recent call last):
#     File "/u/home/a/aflynnca/.nextflow/assets/pgscatalog/pgsc_calc/bin/samplesheet_to_json.py", line 6, in <module>
#       import pandas as pd
#   ModuleNotFoundError: No module named 'pandas'
#
# Work dir:
#   /u/project/pasaniuc/aflynnca/projects/20241015_asd_pgs/20241024_asd_pgs/work/9c/ce6df62cc3012cc70f7a13eb983d62
#
# Tip: when you have fixed the problem you can continue the execution adding the option `-resume` to the run command line
#
#
# ERROR: No scores calculated!
#
#
#
# (plink2_run)
# : 1

# %%
ls
# Out:
# ls
# get_asd_pgs_sh.ipynb        PGS000327.txt  run_pgs_on_local_sh.ipynb
# PGS000327_hmPOS_GRCh38.txt  results        work
# (plink2_run)
# : 1

# %%
which python
# Out:
# which python
# ~/.conda/envs/plink2_run/bin/python
# (plink2_run)
# : 1

# %%
plink2 --version
# Out:
# plink2 --version
# PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)
# (plink2_run)
# : 1

# %%
conda install -c bioconda plink2
# Out:
# conda install -c bioconda plink2
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /u/home/a/aflynnca/.conda/envs/plink2_run
#
#   added / updated specs:
#     - plink2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB
#     blas-1.0                   |         openblas          46 KB
#     libgfortran-ng-11.2.0      |       h00389a5_1          20 KB
#     libgfortran5-11.2.0        |       h1234567_1         2.0 MB
#     libopenblas-0.3.21         |       h043d6bf_0         5.4 MB
#     nomkl-3.0                  |                0          46 KB
#     openblas-0.3.21            |       h06a4308_0          12 KB
#     openblas-devel-0.3.21      |       h06a4308_0          81 KB
#     plink2-2.00a2.3            |       hb2a7ceb_2         6.9 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:        14.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   blas               pkgs/main/linux-64::blas-1.0-openblas
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-11.2.0-h00389a5_1
#   libgfortran5       pkgs/main/linux-64::libgfortran5-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libopenblas        pkgs/main/linux-64::libopenblas-0.3.21-h043d6bf_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   nomkl              pkgs/main/linux-64::nomkl-3.0-0
#   openblas           pkgs/main/linux-64::openblas-0.3.21-h06a4308_0
#   openblas-devel     pkgs/main/linux-64::openblas-devel-0.3.21-h06a4308_0
#   plink2             bioconda/linux-64::plink2-2.00a2.3-hb2a7ceb_2
