# %%
wget http://resource.psychencode.org/Datasets/Integrative/Promoter-anchored_chromatin_loops.bed
# Out:
# --2024-12-09 08:41:31--  http://resource.psychencode.org/Datasets/Integrative/Promoter-anchored_chromatin_loops.bed
# Resolving resource.psychencode.org (resource.psychencode.org)... 52.72.81.43
# Connecting to resource.psychencode.org (resource.psychencode.org)|52.72.81.43|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5975152 (5.7M) [application/vnd.realvnc.bed]
# Saving to: ‘Promoter-anchored_chromatin_loops.bed’
#
# 100%[======================================>] 5,975,152   6.89MB/s   in 0.8s
#
# 2024-12-09 08:41:37 (6.89 MB/s) - ‘Promoter-anchored_chromatin_loops.bed’ saved [5975152/5975152]
