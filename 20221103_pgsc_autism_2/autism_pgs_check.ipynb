# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3

# %%
conda activate plink2_env
# Out:
# (plink2_env)
# : 1

# %%
module load java/jdk-11.0.14
# Out:
# (plink2_env)
# : 1

# %%
ls /u/project/pasaniuc/afcarrol/Projects/20221017_pgsc_calc_test/
# Out:
# manual_pgs.ipynb  pgs_calc_autism_setup.ipynb   results
# nextflow          PGScatalog-pgsc_calc-0a6f0aa  work
# (plink2_env)
# : 1

# %%
/u/project/pasaniuc/afcarrol/Projects/20221017_pgsc_calc_test/nextflow run pgscatalog/pgsc_calc -r v1.2.0 \
    -profile conda \
    --input /u/project/pasaniuc/afcarrol/Projects/20221020_pgsc_calc_autism/SPARK_full.csv --target_build GRCh38 \
    --pgs_id PGS000327 \
    --min_overlap 0.001
# Out:
# _calc_test/nextflow run pgscatalog/pgsc_calc -r v1.2.0 \
#     -profile conda \
# calc_autism/SPARK_full.csv --target_build GRCh38 \20221020_pgsc_
#     --pgs_id PGS000327 \
#     --min_overlap 0.001
# N E X T F L O W  ~  version 22.10.1
# Launching `https://github.com/pgscatalog/pgsc_calc` [lethal_bell] DSL2 - revision: 7e11510b93 [v1.2.0]
#
#
# ------------------------------------------------------
#   pgscatalog/pgsc_calc v1.2.0
# ------------------------------------------------------
# Core Nextflow options
#   revision    : v1.2.0
#   runName     : lethal_bell
#   launchDir   : /u/project/pasaniuc/afcarrol/Projects/20221103_pgsc_autism_2
#   workDir     : /u/project/pasaniuc/afcarrol/Projects/20221103_pgsc_autism_2/work
#   projectDir  : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc
#   userName    : afcarrol
#   profile     : conda
#   configFiles : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc/nextflow.config
#
# Input/output options
#   input       : /u/project/pasaniuc/afcarrol/Projects/20221020_pgsc_calc_autism/SPARK_full.csv
#   pgs_id      : PGS000327
#   pgp_id      : null
#   trait_efo   : null
#   target_build: GRCh38
#
# Variant Matching QC & Filtering
#   min_overlap : 0.001
#
# Institutional config options
#   hostnames   : [:]
#
# Max job request options
#   max_cpus    : 2
#   max_memory  : 16.GB
#
# Generic options
#   enable_conda: true
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use pgscatalog/pgsc_calc for your analysis please cite:
#
# * The Polygenic Score Catalog
#   https://doi.org/10.1038/s41588-021-00783-5
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/pgscatalog/pgsc_calc/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (2)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (2)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (2)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 10)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 16)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 9)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 1)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 6)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 13)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 5)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 12)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 15)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 14)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 11)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 3)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 4)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 7)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 8)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 2)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 18)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 21)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 20)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 19)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 17)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 22)
#
# executor >  local (2)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 10)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 16)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 9)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 1)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 6)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 13)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 5)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 12)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 15)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 14)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 11)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 3)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 4)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 7)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 8)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 2)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 18)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 21)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 20)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 19)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 17)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 22)
#
# executor >  local (3)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 10)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 16)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 9)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 1)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 6)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 13)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 5)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 12)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 15)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 14)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 11)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 3)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 4)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 7)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 8)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 2)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 18)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 21)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 20)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 19)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 17)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 22)
#
# executor >  local (3)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 10)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 16)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 9)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 1)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 6)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 13)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 5)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 12)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 15)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 14)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 11)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 3)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 4)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 7)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 8)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 2)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 18)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 21)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 20)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 19)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 17)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 22)
#
# executor >  local (4)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 10)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 16)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 9)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 1)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 6)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 13)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 5)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 12)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 15)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 14)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 11)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 3)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 4)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 7)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 8)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 2)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 18)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 21)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 20)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 19)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 17)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 22)
#
# executor >  local (4)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 10)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 16)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 9)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 1)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 6)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 13)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 5)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 12)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 15)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 14)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 11)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 3)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 4)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 7)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 8)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 2)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 18)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 21)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 20)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 19)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 17)
# [skipping] Stored process > PGSCATALOG_PGSCALC:PGSCALC:MAKE_COMPATIBLE:PLINK2_RELABELPVAR (SPARK chromosome 22)
#
# executor >  local (4)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# INFO: Scores ready for calculation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# executor >  local (5)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [1e/5d840a] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# INFO: Scores ready for calculation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# executor >  local (6)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [9e/55d329] process > PGSCATALOG_PGSCALC:PGSCALC:... [  4%] 1 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# INFO: Scores ready for calculation
#
# executor >  local (7)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [93/c9ccf5] process > PGSCATALOG_PGSCALC:PGSCALC:... [  9%] 2 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
#
# executor >  local (8)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [8e/b97cf6] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 13%] 3 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
#
# executor >  local (8)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [8e/b97cf6] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 13%] 3 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (9)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [40/9a4310] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 18%] 4 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (10)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [78/b88f9a] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 22%] 5 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (11)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [f4/f72c54] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 27%] 6 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (11)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [f4/f72c54] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 27%] 6 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (12)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [1e/e0ddea] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 31%] 7 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (13)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [1e/e0ddea] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 36%] 8 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (14)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [3b/894987] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 40%] 9 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (14)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [3b/894987] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 40%] 9 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (14)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [69/8eb2d9] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 45%] 10 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (15)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [dc/00f660] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 45%] 10 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (16)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [07/e6bfba] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 50%] 11 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (17)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [52/230f8d] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 54%] 12 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (18)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [52/230f8d] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 59%] 13 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (19)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [0e/60ff06] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 63%] 14 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (20)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [e3/807ddd] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 68%] 15 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# executor >  local (21)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [c4/2ca6f5] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 72%] 16 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (22)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ab/832e1a] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 77%] 17 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (23)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [47/21d2c9] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 81%] 18 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (24)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [29/68c18a] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 86%] 19 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (25)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [95/1275af] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 90%] 20 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (25)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [95/1275af] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 90%] 20 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (25)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [95/1275af] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 95%] 21 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (26)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [0c/cfc7da] process > PGSCATALOG_PGSCALC:PGSCALC:... [ 95%] 21 of 22
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (26)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [0c/cfc7da] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (27)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [0c/cfc7da] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22 ✔
# [2f/eb299b] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (27)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [0c/cfc7da] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22 ✔
# [2f/eb299b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (28)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [0c/cfc7da] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22 ✔
# [2f/eb299b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ff/766032] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (28)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [0c/cfc7da] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22 ✔
# [2f/eb299b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ff/766032] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
#
# executor >  local (29)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [0c/cfc7da] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22 ✔
# [2f/eb299b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ff/766032] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [e6/3a913b] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
#
# executor >  local (29)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [0c/cfc7da] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22 ✔
# [2f/eb299b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ff/766032] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [e6/3a913b] process > PGSCATALOG_PGSCALC:PGSCALC:... [  0%] 0 of 1
#
# executor >  local (29)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [0c/cfc7da] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22 ✔
# [2f/eb299b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ff/766032] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [e6/3a913b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# -[pgscatalog/pgsc_calc] Pipeline completed successfully-
# Please remember to cite polygenic score authors if you publish with them!
# Check the output report for citation details
#
# executor >  local (29)
# [74/c6b200] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ee/9adaa2] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [61/8c8e9b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [skipped  ] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22, stored:...
# [-        ] process > PGSCATALOG_PGSCALC:PGSCALC:... -
# [ed/85b5e6] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [0c/cfc7da] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 22 of 22 ✔
# [2f/eb299b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [ff/766032] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# [e6/3a913b] process > PGSCATALOG_PGSCALC:PGSCALC:... [100%] 1 of 1 ✔
# -[pgscatalog/pgsc_calc] Pipeline completed successfully-
# Please remember to cite polygenic score authors if you publish with them!
# Check the output report for citation details
# Completed at: 03-Nov-2022 12:47:55
# Duration    : 20m 29s
# CPU hours   : 0.7
# Succeeded   : 29
#
#
# (plink2_env)
# : 1
