# %%
import pandas as pd
import tempfile
from os.path import join
import urllib.request
import subprocess
import os

# %%
def run(df_chrom_pos: pd.DataFrame, chain: str, verbose: bool = False, bin_path: str = "liftOver"):

    """Lift over between genome assembly
    Download appropriate chain file from
    hg38->hg19 http://hgdownload.cse.ucsc.edu/goldenpath/hg38/liftOver/hg38ToHg19.over.chain.gz
    hg19->hg38 http://hgdownload.cse.ucsc.edu/goldenpath/hg19/liftOver/hg19ToHg38.over.chain.gz
    Download executable from http://hgdownload.soe.ucsc.edu/admin/exe/
    (1) chmod +x liftOver
    (2) include to the path, so the program can call liftOver 

    Parameters
    ----------
    df_chrom_pos: pd.DataFrame
        where the 1st column are the chromosomes, without `chr`
        and the 2nd column are the positions
    chain : str
        chain file

    Returns
    -------
    index of df_chrom_pos and the corresponding positions
    SNP positions after the liftOver, unmapped SNPs are returned as -1
    """

    df_chrom_pos = df_chrom_pos.copy()
    df_chrom_pos.columns = ["CHROM", "POS"]

    assert chain in [
        "hg38->hg19",
        "hg19->hg38",
    ], "Currently only these two chain files are supported"
    url_dict = {
        "hg38->hg19": "http://hgdownload.cse.ucsc.edu/goldenpath/hg38/liftOver/hg38ToHg19.over.chain.gz",
        "hg19->hg38": "http://hgdownload.cse.ucsc.edu/goldenpath/hg19/liftOver/hg19ToHg38.over.chain.gz",
    }
    df_chrom_pos = pd.DataFrame(
        {
            "CHROM": "chr" + df_chrom_pos["CHROM"].astype(str),
            "POS0": df_chrom_pos["POS"] - 1,
            "POS": df_chrom_pos["POS"],
            "ID": df_chrom_pos.index.values.astype(str),
        }
    )

    tmp_dir = tempfile.TemporaryDirectory()
    old_file = join(tmp_dir.name, "old.bed")
    chain_file = join(tmp_dir.name, "chain.gz")
    new_file = join(tmp_dir.name, "new.bed")
    unmapped_file = join(tmp_dir.name, "unmapped.txt")

    urllib.request.urlretrieve(url_dict[chain], chain_file)
    df_chrom_pos.to_csv(old_file, sep="\t", index=False, header=False)
    cmd = f"{bin_path} {old_file} {chain_file} {new_file} {unmapped_file}"
    subprocess.check_call(cmd, shell=True)

    # read the mapped data frame, SNPs with ambiguous mapping are dropped
    df_new = pd.read_csv(
        new_file, sep="\t", header=None, names=["CHROM", "POS0", "POS", "ID"]
    ).drop_duplicates(subset=["ID"], keep=False)
    # count number of lines starting with a #
    n_unmapped = sum(1 for line in open(unmapped_file) if line.startswith("#"))
    print(f"{n_unmapped} un-mapped variants")

    tmp_dir.cleanup()

    # ambiguous mapping or unmapped SNPs are -1, return
    df_ret = (
        df_new.set_index("ID")
        .reindex(df_chrom_pos.index.values)[["POS"]]
        .fillna(-1)
        .astype(int)
    )

    df_ret.index.name = df_chrom_pos.index.name
    return df_ret

# %%
os.getcwd()
# Out:
# '/u/project/pasaniuc/afcarrol/Projects/20231219_SPARK_AFR_ASD_GWAS'

# %%
os.listdir()
# Out:
# ['spark_afr_gwas.sh',
#  'pgen_indv.sh',
#  'temp_individuals_list.log',
#  'chr1.psam',
#  'input_files',
#  'output_files',
#  'plink2.log',
#  '.ipynb_checkpoints',
#  'combine_asd_gwas_ADD_results.ipynb',
#  'manhattan_plot_spark_afr_asd.pdf',
#  'manhattan_plot_spark_afr_asd_unre.pdf',
#  'manhattan_plot_spark_afr_asd.jpg',
#  'QQ_plot_spark_asd_unre.jpeg',
#  'spark_afr_asd_unre_gwas_prscs.txt',
#  'convert_SAUG_hg38_to_hg19.ipynb']

# %%
# Load your data into a DataFrame
df_chrom_pos = pd.read_csv("/u/home/a/afcarrol/project-pasaniuc/Projects/20231219_SPARK_AFR_ASD_GWAS/output_files/ADD_1-22_spark_afr_asd.csv", sep=",")

# %%
df_chrom_pos.head()
# Out:
#    CHROM     POS               ID REF ALT A1 TEST  OBS_CT        OR  \
# 0      1  856473  chr1:856473:G:A   G   A  A  ADD     534  2.235080
# 1      1  858952  chr1:858952:G:A   G   A  A  ADD    2087  0.995816
# 2      1  859842  chr1:859842:C:G   C   G  G  ADD    2087  1.471630
# 3      1  863421  chr1:863421:G:A   G   A  A  ADD    2087  1.402910
# 4      1  864119  chr1:864119:T:C   T   C  C  ADD    2087  1.397430
#
#    LOG(OR)_SE    Z_STAT         P
# 0    1.207670  0.665974  0.505428
# 1    0.241259 -0.017377  0.986136
# 2    0.352725  1.095400  0.273343
# 3    0.350893  0.964810  0.334640
# 4    0.350321  0.955213  0.339470

# %%
result = run(df_chrom_pos[['CHROM', 'POS']], chain="hg38->hg19", bin_path="/u/home/a/afcarrol/software/liftOver/liftOver")
# Out:
# Reading liftover chains
# Mapping coordinates
# 9371 un-mapped variants

# %%
result.shape
# Out:
# (8104394, 1)

# %%
result.head
# Out:
# <bound method NDFrame.head of               POS
# 0          791853
# 1          794332
# 2          795222
# 3          798801
# 4          799499
# ...           ...
# 8104389  51164109
# 8104390  51164115
# 8104391  51164287
# 8104392  51165664
# 8104393  51174939
#
# [8104394 rows x 1 columns]>

# %%
# Find the number of entries equal to -1
num_entries_equal_to_minus_one = (result == -1).sum().sum()

# Print the result
print("Number of entries equal to -1:", num_entries_equal_to_minus_one)
# Out:
# Number of entries equal to -1: 9371

# %%
result.columns = ['hg19']

# %%
merged_df = pd.merge(df_chrom_pos, result, left_index=True, right_index=True)

# %%
merged_df.head()
# Out:
#    CHROM     POS               ID REF ALT A1 TEST  OBS_CT        OR  \
# 0      1  856473  chr1:856473:G:A   G   A  A  ADD     534  2.235080
# 1      1  858952  chr1:858952:G:A   G   A  A  ADD    2087  0.995816
# 2      1  859842  chr1:859842:C:G   C   G  G  ADD    2087  1.471630
# 3      1  863421  chr1:863421:G:A   G   A  A  ADD    2087  1.402910
# 4      1  864119  chr1:864119:T:C   T   C  C  ADD    2087  1.397430
#
#    LOG(OR)_SE    Z_STAT         P    hg19
# 0    1.207670  0.665974  0.505428  791853
# 1    0.241259 -0.017377  0.986136  794332
# 2    0.352725  1.095400  0.273343  795222
# 3    0.350893  0.964810  0.334640  798801
# 4    0.350321  0.955213  0.339470  799499

# %%
write.csv(merged_df, file = "/u/project/pasaniuc/afcarrol/Projects/20231219_SPARK_AFR_ASD_GWAS/hg19_hg38_ADD_1-22_spark_afr_asd.csv", row.names = FALSE)
# Out:
#   File "/tmp/ipykernel_30091/1622449111.py", line 1
#     write.csv(merged_df, file = "/u/project/pasaniuc/afcarrol/Projects/20231219_SPARK_AFR_ASD_GWAS/hg19_hg38_ADD_1-22_spark_afr_asd.csv", row.names = FALSE)
#                                                                                                                                           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
merged_df.to_csv('/u/project/pasaniuc/afcarrol/Projects/20231219_SPARK_AFR_ASD_GWAS/hg19_hg38_ADD_1-22_spark_afr_asd.csv', index=False)
