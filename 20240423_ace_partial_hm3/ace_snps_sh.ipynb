# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3/2020.11
conda activate plink2_env
# Out:
# (plink2_env)
# : 1

# %%
# Set the filename as a variable
filename="/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/merged_output_2"
# Out:
# (plink2_env) (plink2_env)
# : 1

# %%
# Use the variable in a Plink command
plink2 --pfile "${filename}" --write-snplist
# Out:
# (plink2_env) PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to plink2.log.
# Options in effect:
#   --pfile /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/merged_output_2
#   --write-snplist
#
# Start time: Tue Apr 23 18:19:40 2024
# 193121 MiB RAM detected; reserving 96560 MiB for main workspace.
# Using up to 36 threads (change this with --threads).
# 55254922 variants loaded from
# /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/merged_output_2.pvar.
# Note: No phenotype data present.
# --write-snplist: Variant IDs written to plink2.snplist .
# End time: Tue Apr 23 18:19:48 2024
# (plink2_env)
# : 1
