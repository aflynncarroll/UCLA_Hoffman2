# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3
#120G

# %%
ls /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/
# Out:
# ace_hm3_chr10.log   ace_hm3_chr15.psam  ace_hm3_chr20.log   ace_hm3_chr4.psam
# ace_hm3_chr10.pgen  ace_hm3_chr15.pvar  ace_hm3_chr20.pgen  ace_hm3_chr4.pvar
# ace_hm3_chr10.psam  ace_hm3_chr16.log   ace_hm3_chr20.psam  ace_hm3_chr5.log
# ace_hm3_chr10.pvar  ace_hm3_chr16.pgen  ace_hm3_chr20.pvar  ace_hm3_chr5.pgen
# ace_hm3_chr11.log   ace_hm3_chr16.psam  ace_hm3_chr21.log   ace_hm3_chr5.psam
# ace_hm3_chr11.pgen  ace_hm3_chr16.pvar  ace_hm3_chr21.pgen  ace_hm3_chr5.pvar
# ace_hm3_chr11.psam  ace_hm3_chr17.log   ace_hm3_chr21.psam  ace_hm3_chr6.log
# ace_hm3_chr11.pvar  ace_hm3_chr17.pgen  ace_hm3_chr21.pvar  ace_hm3_chr6.pgen
# ace_hm3_chr12.log   ace_hm3_chr17.psam  ace_hm3_chr22.log   ace_hm3_chr6.psam
# ace_hm3_chr12.pgen  ace_hm3_chr17.pvar  ace_hm3_chr22.pgen  ace_hm3_chr6.pvar
# ace_hm3_chr12.psam  ace_hm3_chr18.log   ace_hm3_chr22.psam  ace_hm3_chr7.log
# ace_hm3_chr12.pvar  ace_hm3_chr18.pgen  ace_hm3_chr22.pvar  ace_hm3_chr7.pgen
# ...

# %%
ls /u/home/a/afcarrol/project-pasaniuc/Projects/20240423_ace_partial_hm3/rfmix_out/
# Out:
# chr10.fb.tsv   chr14.sis.tsv  chr19.rfmix.Q  chr2.msp.tsv  chr6.msp.tsv
# chr10.msp.tsv  chr15.fb.tsv   chr19.sis.tsv  chr2.rfmix.Q  chr6.rfmix.Q
# chr10.rfmix.Q  chr15.msp.tsv  chr1.fb.tsv    chr2.sis.tsv  chr6.sis.tsv
# chr10.sis.tsv  chr15.rfmix.Q  chr1.msp.tsv   chr3.fb.tsv   chr7.fb.tsv
# chr11.fb.tsv   chr15.sis.tsv  chr1.rfmix.Q   chr3.lanc     chr7.msp.tsv
# chr11.msp.tsv  chr16.fb.tsv   chr1.sis.tsv   chr3.msp.tsv  chr7.rfmix.Q
# chr11.rfmix.Q  chr16.msp.tsv  chr20.fb.tsv   chr3.rfmix.Q  chr7.sis.tsv
# chr11.sis.tsv  chr16.rfmix.Q  chr20.msp.tsv  chr3.sis.tsv  chr8.fb.tsv
# chr12.fb.tsv   chr16.sis.tsv  chr20.rfmix.Q  chr4.fb.tsv   chr8.msp.tsv
# chr12.msp.tsv  chr17.fb.tsv   chr20.sis.tsv  chr4.lanc     chr8.rfmix.Q
# chr12.rfmix.Q  chr17.msp.tsv  chr21.fb.tsv   chr4.msp.tsv  chr8.sis.tsv
# chr12.sis.tsv  chr17.rfmix.Q  chr21.msp.tsv  chr4.rfmix.Q  chr9.fb.tsv
# chr13.fb.tsv   chr17.sis.tsv  chr21.rfmix.Q  chr4.sis.tsv  chr9.msp.tsv
# ...

# %%
for chrom in {1..22}
do

pfile=/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr${chrom}
rfmix_msp=/u/home/a/afcarrol/project-pasaniuc/Projects/20240423_ace_partial_hm3/rfmix_out/chr${chrom}.msp.tsv
out_prefix=/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr${chrom}.lanc


admix lanc-convert \
    --pfile ${pfile} \
    --rfmix ${rfmix_msp} \
    --out ${out_prefix}           

done
# Out:
# 2024-04-24 11:26.57 [info     ] Received parameters:
# lanc-convert
#   --pfile=/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr1
#   --out=/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr1.lanc
#   --rfmix=/u/home/a/afcarrol/project-pasaniuc/Projects/20240423_ace_partial_hm3/rfmix_out/chr1.msp.tsv
#   --raw=None
# 2024-04-24 11:26.57 [info     ] Reading rfmix file: /u/home/a/afcarrol/project-pasaniuc/Projects/20240423_ace_partial_hm3/rfmix_out/chr1.msp.tsv
# 2024-04-24 11:27.02 [info     ] Obtaining local ancestry admix.Lanc object with n_snp x n_indiv = 87085 x 2612, use `lanc.dask()` to convert to dask array.
# 2024-04-24 11:27.02 [info     ] Writing lanc file: /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr1.lanc
# ...

# %%
for chrom in {1..22}
do
pfile=/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr${chrom}
weights=/u/home/a/afcarrol/project-pasaniuc/Projects/20240229_ace_partial_pgs/grove_hg19_asd.tsv
out_prefix=/u/home/a/afcarrol/project-pasaniuc/Projects/20240423_ace_partial_hm3/part_pgs/chr${chrom}

admix calc-partial-pgs \
    --plink-path ${pfile}.pgen \
    --weights-path ${weights} \
    --dset-build 'hg38->hg19' \
    --out ${out_prefix}

done
# Out:
# 2024-04-24 11:31.33 [info     ] Received parameters:
# calc-partial-pgs
#   --plink_path=/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr1.pgen
#   --weights_path=/u/home/a/afcarrol/project-pasaniuc/Projects/20240229_ace_partial_pgs/grove_hg19_asd.tsv
#   --out=/u/home/a/afcarrol/project-pasaniuc/Projects/20240423_ace_partial_hm3/part_pgs/chr1
#   --ref_plink_path=None
#   --ref_pops=None
#   --weight_col=WEIGHT
#   --dset_build=hg38->hg19
#   --weights_build=None
#   --ref_pop_col=Population
# 2024-04-24 11:31.33 [info     ] Scoring for dataset 1/1: /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr1
# Reading liftover chains
# Mapping coordinates
# 0 un-mapped variants
# 2024-04-24 11:31.36 [info     ] matched #SNPs=681/87085
# admix.data.calc_partial_pgs: 100%|███████| 2612/2612 [00:00<00:00, 15214.63it/s]
# ...

# %%
ls /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles
# Out:
# ace_hm3_chr10.lanc  ace_hm3_chr15.psam  ace_hm3_chr20.log   ace_hm3_chr4.pvar
# ace_hm3_chr10.log   ace_hm3_chr15.pvar  ace_hm3_chr20.pgen  ace_hm3_chr5.lanc
# ace_hm3_chr10.pgen  ace_hm3_chr16.lanc  ace_hm3_chr20.psam  ace_hm3_chr5.log
# ace_hm3_chr10.psam  ace_hm3_chr16.log   ace_hm3_chr20.pvar  ace_hm3_chr5.pgen
# ace_hm3_chr10.pvar  ace_hm3_chr16.pgen  ace_hm3_chr21.lanc  ace_hm3_chr5.psam
# ace_hm3_chr11.lanc  ace_hm3_chr16.psam  ace_hm3_chr21.log   ace_hm3_chr5.pvar
# ace_hm3_chr11.log   ace_hm3_chr16.pvar  ace_hm3_chr21.pgen  ace_hm3_chr6.lanc
# ace_hm3_chr11.pgen  ace_hm3_chr17.lanc  ace_hm3_chr21.psam  ace_hm3_chr6.log
# ace_hm3_chr11.psam  ace_hm3_chr17.log   ace_hm3_chr21.pvar  ace_hm3_chr6.pgen
# ace_hm3_chr11.pvar  ace_hm3_chr17.pgen  ace_hm3_chr22.lanc  ace_hm3_chr6.psam
# ace_hm3_chr12.lanc  ace_hm3_chr17.psam  ace_hm3_chr22.log   ace_hm3_chr6.pvar
# ace_hm3_chr12.log   ace_hm3_chr17.pvar  ace_hm3_chr22.pgen  ace_hm3_chr7.lanc
# ...
