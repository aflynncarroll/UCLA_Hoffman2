# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
ace_snps <- read.table("plink2.snplist")

# %%
head(ace_snps)
# Out:
#   V1
# 1 chr10:12040:G:A
# 2 chr10:14470:C:T
# 3 chr10:31093:GAC:G
# 4 chr10:36953:G:C
# 5 chr10:37005:C:A
# 6 chr10:40467:A:C

# %%
hm3_snps <- read.table("../20230117_spark_pca_update/hm3_snp_pos.txt")

# %%
head(hm3_snps)
# Out:
#   V1
# 1 1:817341
# 2 1:818802
# 3 1:825532
# 4 1:833068
# 5 1:843942
# 6 1:903175

# %%
ace_snps$V2 <- gsub("^chr", "", gsub("^(chr[^:]+:[^:]+):.*", "\\1", ace_snps$V1))

# %%
head(ace_snps)
# Out:
#   V1                V2
# 1 chr10:12040:G:A   10:12040
# 2 chr10:14470:C:T   10:14470
# 3 chr10:31093:GAC:G 10:31093
# 4 chr10:36953:G:C   10:36953
# 5 chr10:37005:C:A   10:37005
# 6 chr10:40467:A:C   10:40467

# %%
dim(ace_snps)
# Out:
# [1] 55254922        2

# %%
ace_sub <- ace_snps[ace_snps$V2 %in% hm3_snps$V1,]

# %%
table(ace_sub$V2)
# Out:
#  1:100000723  1:100003060  1:100007048  1:100008900  1:100010150  1:100011106
#            1            1            1            1            1            1
#  1:100011259  1:100016840  1:100016984  1:100017222  1:100018449  1:100020432
#            1            1            1            1            1            1
#  1:100022621  1:100023572  1:100023708  1:100025136  1:100026912  1:100027311
#            1            1            1            1            1            1
#  1:100029836  1:100031535  1:100032479  1:100037134  1:100038716  1:100040859
#            1            1            1            1            1            1
#  1:100045118  1:100049941  1:100054755  1:100057980  1:100062644  1:100067831
#            1            1            1            1            1            1
#  1:100068404  1:100077082  1:100078406  1:100081035   1:10008117  1:100091705
#            1            1            1            1            1            1
# ...

# %%
dim(ace_sub)
# Out:
# [1] 1052816       2

# %%
head(ace_sub)
# Out:
#     V1              V2
# 422 chr10:80130:C:T 10:80130
# 523 chr10:85696:T:C 10:85696
# 588 chr10:89716:T:G 10:89716
# 592 chr10:89768:G:A 10:89768
# 595 chr10:89913:A:G 10:89913
# 698 chr10:97603:G:A 10:97603

# %%
write.csv(ace_sub, "ace_sub_table.csv")

# %%
writeLines(as.character(ace_sub$V1), con = "filtered_snps_hm3.txt")
