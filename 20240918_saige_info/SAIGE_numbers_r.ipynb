# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
ace_saige <- read.table("/u/project/geschwind/shared/GWAS/20241112_saige_run/saige_out/ACE_AFR_marker_chr1-22_vcf.txt")

# %%
head(ace_saige)
# Out:
#   V1  V2    V3              V4      V5      V6         V7         V8
# 1 CHR POS   MarkerID        Allele1 Allele2 AC_Allele2 AF_Allele2 MissingRate
# 2 10  45349 chr10:45349:G:A G       A       225        0.116822   0.0280374
# 3 10  45402 chr10:45402:T:C C       T       568        0.294912   0.0280374
# 4 10  48353 chr10:48353:A:T A       T       22         0.0114226  0
# 5 10  48486 chr10:48486:C:T T       C       928        0.481828   0.0280374
# 6 10  48601 chr10:48601:C:A C       A       705        0.366044   0.0280374
#   V9        V10      ... V14          V15    V16       V17        V18    V19
# 1 BETA      SE       ... p.value.NA   Is.SPA AF_case   AF_ctrl    N_case N_ctrl
# 2 -0.015262 0.207721 ... 9.414294E-01 false  0.113687  0.119608   453    510
# 3 -0.204881 0.147865 ... 1.658721E-01 false  0.289183  0.3        453    510
# 4 0.891636  0.536315 ... 9.640772E-02 false  0.0154525 0.00784314 453    510
# ...

# %%
# Set the first row as column names
colnames(ace_saige) <- ace_saige[1, ]

# Delete the first row
ace_saige <- ace_saige[-1, ]

# %%
head(ace_saige)
