# %% [markdown]
# https://www.pgscatalog.org/publication/PGP000098/
# PGS000327

# %%
#. /u/local/Modules/default/init/modules.sh
#module load anaconda3/2020.11

# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3

# %%
#pwd
# Out:
# pwd
# /u/project/pasaniuc/afcarrol/Projects/20221020_pgs_calc_autism
# (plink2_env)
# : 1

# %%
conda activate plink2_env
# Out:
# (plink2_env)
# : 1

# %%
module load java/jdk-11.0.14
# Out:
# (plink2_env)
# : 1

# %%
#module load plink
# Out:
# (plink2_env)
# : 1

# %%
#/u/project/pasaniuc/afcarrol/Projects/20221017_pgs_calc_test/nextflow

# %%
#pip install pgscatalog-utils
# Out:
# pip install pgscatalog-utils
# ...
#   Using cached pgscatalog_utils-0.2.0-py3-none-any.whl (58 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 600.3/600.3 kB 20.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 28.8 MB/s eta 0:00:000:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 33.5 MB/s eta 0:00:000:00:010:00:01
# ...
#   Using cached pandas_schema-0.3.6-py3-none-any.whl (21 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 35.5 MB/s eta 0:00:000:00:010:00:01
# ...
#   Using cached pyliftover-0.4.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.5/631.5 kB 24.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# ...

# %%
#Rscript -e 'install.packages("httr", repos = "http://cran.us.r-project.org")'
# Out:
# //cran.us.r-project.org")'es("httr", repos = "http:
# also installing the dependencies ‘sys’, ‘askpass’, ‘curl’, ‘openssl’
#
# trying URL 'http://cran.us.r-project.org/src/contrib/sys_3.4.1.tar.gz'
# Content type 'application/x-gzip' length 20131 bytes (19 KB)
# ...
# downloaded 19 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/askpass_1.1.tar.gz'
# Content type 'application/x-gzip' length 5730 bytes
# ...
# downloaded 5730 bytes
#
# trying URL 'http://cran.us.r-project.org/src/contrib/curl_4.3.3.tar.gz'
# Content type 'application/x-gzip' length 670416 bytes (654 KB)
# ...
# downloaded 654 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/openssl_2.0.4.tar.gz'
# Content type 'application/x-gzip' length 1205702 bytes (1.1 MB)
# ...
# downloaded 1.1 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/httr_1.4.4.tar.gz'
# Content type 'application/x-gzip' length 161140 bytes (157 KB)
# ...
# downloaded 157 KB
#
# * installing *source* package ‘sys’ ...
# ...

# %%
#Rscript -e 'install.packages("dplyr", repos = "http://cran.us.r-project.org")'
# Out:
# ://cran.us.r-project.org")'s("dplyr", repos = "http
# also installing the dependencies ‘cli’, ‘fansi’, ‘pkgconfig’, ‘withr’, ‘utf8’, ‘generics’, ‘lifecycle’, ‘tibble’, ‘tidyselect’, ‘vctrs’, ‘pillar’
#
# trying URL 'http://cran.us.r-project.org/src/contrib/cli_3.4.1.tar.gz'
# Content type 'application/x-gzip' length 540044 bytes (527 KB)
# ...
# downloaded 527 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/fansi_1.0.3.tar.gz'
# Content type 'application/x-gzip' length 481163 bytes (469 KB)
# ...
# downloaded 469 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/pkgconfig_2.0.3.tar.gz'
# Content type 'application/x-gzip' length 6080 bytes
# ...
# downloaded 6080 bytes
#
# trying URL 'http://cran.us.r-project.org/src/contrib/withr_2.5.0.tar.gz'
# Content type 'application/x-gzip' length 102089 bytes (99 KB)
# ...
# downloaded 99 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/utf8_1.2.2.tar.gz'
# Content type 'application/x-gzip' length 240327 bytes (234 KB)
# ...

# %%
#Rscript -e 'install.packages("ggplot2", repos = "http://cran.us.r-project.org")'
# Out:
# tp://cran.us.r-project.org")'"ggplot2", repos = "ht
# also installing the dependencies ‘colorspace’, ‘farver’, ‘labeling’, ‘munsell’, ‘RColorBrewer’, ‘viridisLite’, ‘gtable’, ‘isoband’, ‘scales’
#
# trying URL 'http://cran.us.r-project.org/src/contrib/colorspace_2.0-3.tar.gz'
# Content type 'application/x-gzip' length 2199185 bytes (2.1 MB)
# ...
# downloaded 2.1 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/farver_2.1.1.tar.gz'
# Content type 'application/x-gzip' length 1274363 bytes (1.2 MB)
# ...
# downloaded 1.2 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/labeling_0.4.2.tar.gz'
# Content type 'application/x-gzip' length 10156 bytes
# ...
# downloaded 10156 bytes
#
# trying URL 'http://cran.us.r-project.org/src/contrib/munsell_0.5.0.tar.gz'
# Content type 'application/x-gzip' length 182653 bytes (178 KB)
# ...
# downloaded 178 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/RColorBrewer_1.1-3.tar.gz'
# Content type 'application/x-gzip' length 11638 bytes (11 KB)
# ...

# %%
#Rscript -e 'install.packages("DT", repos = "http://cran.us.r-project.org")'
# Out:
# cran.us.r-project.org")'ages("DT", repos = "http://
# also installing the dependencies ‘lazyeval’, ‘Rcpp’, ‘later’, ‘htmlwidgets’, ‘crosstalk’, ‘promises’
#
# trying URL 'http://cran.us.r-project.org/src/contrib/lazyeval_0.2.2.tar.gz'
# Content type 'application/x-gzip' length 83482 bytes (81 KB)
# ...
# downloaded 81 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/Rcpp_1.0.9.tar.gz'
# Content type 'application/x-gzip' length 2957812 bytes (2.8 MB)
# ...
# downloaded 2.8 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/later_1.3.0.tar.gz'
# Content type 'application/x-gzip' length 63785 bytes (62 KB)
# ...
# downloaded 62 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/htmlwidgets_1.5.4.tar.gz'
# Content type 'application/x-gzip' length 956850 bytes (934 KB)
# ...
# downloaded 934 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/crosstalk_1.2.0.tar.gz'
# Content type 'application/x-gzip' length 296495 bytes (289 KB)
# ...
# downloaded 289 KB
#
# ...

# %%
#Rscript -e 'install.packages("forcats", repos = "http://cran.us.r-project.org")'
# Out:
# tp://cran.us.r-project.org")'"forcats", repos = "ht
# trying URL 'http://cran.us.r-project.org/src/contrib/forcats_0.5.2.tar.gz'
# Content type 'application/x-gzip' length 265815 bytes (259 KB)
# ...
# downloaded 259 KB
#
# * installing *source* package ‘forcats’ ...
# ** package ‘forcats’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (forcats)
#
# The downloaded source packages are in
# 	‘/work/tmp/RtmpMzSvbk/downloaded_packages’
# Updating HTML index of packages in '.Library'
# ...

# %%
#Rscript -e 'install.packages("readr", repos = "http://cran.us.r-project.org")'
# Out:
# ://cran.us.r-project.org")'s("readr", repos = "http
# also installing the dependencies ‘bit’, ‘prettyunits’, ‘bit64’, ‘progress’, ‘clipr’, ‘crayon’, ‘hms’, ‘vroom’, ‘tzdb’
#
# trying URL 'http://cran.us.r-project.org/src/contrib/bit_4.0.4.tar.gz'
# Content type 'application/x-gzip' length 279723 bytes (273 KB)
# ...
# downloaded 273 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/prettyunits_1.1.1.tar.gz'
# Content type 'application/x-gzip' length 10366 bytes (10 KB)
# ...
# downloaded 10 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/bit64_4.0.5.tar.gz'
# Content type 'application/x-gzip' length 135091 bytes (131 KB)
# ...
# downloaded 131 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/progress_1.2.2.tar.gz'
# Content type 'application/x-gzip' length 29506 bytes (28 KB)
# ...
# downloaded 28 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/clipr_0.8.0.tar.gz'
# Content type 'application/x-gzip' length 21898 bytes (21 KB)
# ...
# downloaded 21 KB
#
# ...

# %%
#Rscript -e 'devtools::install_github("r-lib/httr")'
# Out:
# '
# Error in loadNamespace(x) : there is no package called ‘devtools’
# Calls: loadNamespace -> withRestarts -> withOneRestart -> doWithOneRestart
# Execution halted
# (plink2_env)
# : 1

# %%
nextflow run pgscatalog/pgsc_calc -r v1.2.0 -profile test, conda
# Out:
# e test, condapgscatalog/pgsc_calc -r v1.2.0 -profil
# N E X T F L O W  ~  version 21.10.6
# Launching `pgscatalog/pgsc_calc` [nice_blackwell] - revision: 7e11510b93 [v1.2.0]
#
#
# ------------------------------------------------------
#   pgscatalog/pgsc_calc v1.2.0
# ------------------------------------------------------
# Core Nextflow options
#   revision                  : v1.2.0
#   runName                   : nice_blackwell
#   launchDir                 : /u/project/pasaniuc/afcarrol/Projects/20221020_pgs_calc_autism
#   workDir                   : /u/project/pasaniuc/afcarrol/Projects/20221020_pgs_calc_autism/work
#   projectDir                : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc
#   userName                  : afcarrol
#   profile                   : test,
#   configFiles               : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc/nextflow.config
#
# Input/output options
# ...

# %%
#pip install pyyaml
# Out:
# pip install pyyaml
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.9/757.9 kB 18.6 MB/s eta 0:00:000:00:01
# ...
# (plink2_env)
# : 1

# %%
nextflow run pgscatalog/pgsc_calc --help
# Out:
# nextflow run pgscatalog/pgsc_calc --help
# N E X T F L O W  ~  version 21.10.6
# Launching `pgscatalog/pgsc_calc` [distracted_kimura] - revision: 6f3f04296d [master]
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   pgscatalog/pgsc_calc v0.1.2dev
# ------------------------------------------------------
# Typical pipeline command:
#
#   nextflow run pgscatalog/pgsc_calc --input assets/samplesheet.csv --scorefile assets/PGS001229_22.txt -profile docker
#
# Input/output options
#   --input                             [string]  Path to comma-separated file containing information about the samples (a sample sheet)
#   --format                            [string]  Format of the input [default: csv]
# ...

# %%
ls
# Out:
# ls
# autism_pgs.ipynb  chr1_test.csv  results  work
# (plink2_env)
# : 1

# %%
ls -lh /u/project/geschwind/shared/GenomicDatasets-processed/ACE-ANALYSIS/freeze0/SPARK/imputed/
# Out:
# total 86G
# -rw-r--r--. 1 kangchen pasaniuc 1.5K Jul 23 13:49 chr10.log
# -rw-r--r--. 1 kangchen pasaniuc 4.4G Jul 23 13:49 chr10.pgen
# -rw-r--r--. 1 kangchen pasaniuc 1.5M Jul 23 13:48 chr10.psam
# -rw-r--r--. 1 kangchen pasaniuc  41M Jul 23 13:48 chr10.pvar
# -rw-r--r--. 1 kangchen pasaniuc 1.5K Jul 23 13:41 chr11.log
# -rw-r--r--. 1 kangchen pasaniuc 4.3G Jul 23 13:41 chr11.pgen
# -rw-r--r--. 1 kangchen pasaniuc 1.5M Jul 23 13:40 chr11.psam
# -rw-r--r--. 1 kangchen pasaniuc  41M Jul 23 13:40 chr11.pvar
# -rw-r--r--. 1 kangchen pasaniuc 1.5K Jul 23 13:41 chr12.log
# -rw-r--r--. 1 kangchen pasaniuc 4.2G Jul 23 13:41 chr12.pgen
# -rw-r--r--. 1 kangchen pasaniuc 1.5M Jul 23 13:40 chr12.psam
# -rw-r--r--. 1 kangchen pasaniuc  40M Jul 23 13:40 chr12.pvar
# -rw-r--r--. 1 kangchen pasaniuc 1.5K Jul 23 13:22 chr13.log
# -rw-r--r--. 1 kangchen pasaniuc 3.2G Jul 23 13:22 chr13.pgen
# -rw-r--r--. 1 kangchen pasaniuc 1.5M Jul 23 13:22 chr13.psam
# ...

# %%
/u/project/pasaniuc/afcarrol/Projects/20221017_pgs_calc_test/nextflow run pgscatalog/pgsc_calc -r v1.2.0 \
    -profile conda \
    --input chr1_test.csv --target_build GRCh38 \
    --pgs_id PGS000327 \
    --min_overlap 0.01
# Out:
# calc_test/nextflow run pgscatalog/pgsc_calc -r v1.2.0 \
#     -profile conda \
#     --input chr1_test.csv --target_build GRCh38 \
#     --pgs_id PGS000327 \
#     --min_overlap 0.01
# N E X T F L O W  ~  version 22.10.1
# Launching `https://github.com/pgscatalog/pgsc_calc` [sharp_goodall] DSL2 - revision: 7e11510b93 [v1.2.0]
#
#
# ------------------------------------------------------
#   pgscatalog/pgsc_calc v1.2.0
# ------------------------------------------------------
# Core Nextflow options
#   revision    : v1.2.0
#   runName     : sharp_goodall
#   launchDir   : /u/project/pasaniuc/afcarrol/Projects/20221020_pgs_calc_autism
#   workDir     : /u/project/pasaniuc/afcarrol/Projects/20221020_pgs_calc_autism/work
#   projectDir  : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc
#   userName    : afcarrol
#   profile     : conda
#   configFiles : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc/nextflow.config
#
# Input/output options
# ...

# %%
ls
# Out:
# ls
# autism_pgs.ipynb  chr1_test.csv      PGS000327.txt.gz  SPARK_full.csv
# chr1_test_2.csv   chr1_test_vcf.csv  results           work
# (plink2_env)
# : 1

# %%
/u/project/pasaniuc/afcarrol/Projects/20221017_pgs_calc_test/nextflow run pgscatalog/pgsc_calc -r v1.2.0 \
    -profile conda \
    --input SPARK_full.csv --target_build GRCh38 \
    --pgs_id PGS000327 \
    --min_overlap 0.01
# Out:
# calc_test/nextflow run pgscatalog/pgsc_calc -r v1.2.0 \
#     -profile conda \
#     --input SPARK_full.csv --target_build GRCh38 \
#     --pgs_id PGS000327 \
#     --min_overlap 0.01
# N E X T F L O W  ~  version 22.10.1
# Launching `https://github.com/pgscatalog/pgsc_calc` [high_raman] DSL2 - revision: 7e11510b93 [v1.2.0]
#
#
# ------------------------------------------------------
#   pgscatalog/pgsc_calc v1.2.0
# ------------------------------------------------------
# Core Nextflow options
#   revision    : v1.2.0
#   runName     : high_raman
#   launchDir   : /u/project/pasaniuc/afcarrol/Projects/20221020_pgs_calc_autism
#   workDir     : /u/project/pasaniuc/afcarrol/Projects/20221020_pgs_calc_autism/work
#   projectDir  : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc
#   userName    : afcarrol
#   profile     : conda
#   configFiles : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc/nextflow.config
#
# Input/output options
#   input       : SPARK_full.csv
# ...

# %%
##########################################

# %%
/u/project/pasaniuc/afcarrol/Projects/20221017_pgs_calc_test/nextflow run pgscatalog/pgsc_calc -r v1.2.0 \
    -profile conda \
    --input chr1_test.csv --target_build GRCh38 \
    --scorefile PGS000327.txt.gz
# Out:
# calc_test/nextflow run pgscatalog/pgsc_calc -r v1.2.0 \
#     -profile conda \
#     --input chr1_test.csv --target_build GRCh38 \
#     --scorefile PGS000327.txt.gz
# N E X T F L O W  ~  version 22.10.1
# Launching `https://github.com/pgscatalog/pgsc_calc` [sick_marconi] DSL2 - revision: 7e11510b93 [v1.2.0]
#
#
# ------------------------------------------------------
#   pgscatalog/pgsc_calc v1.2.0
# ------------------------------------------------------
# Core Nextflow options
#   revision    : v1.2.0
#   runName     : sick_marconi
#   launchDir   : /u/project/pasaniuc/afcarrol/Projects/20221020_pgs_calc_autism
#   workDir     : /u/project/pasaniuc/afcarrol/Projects/20221020_pgs_calc_autism/work
#   projectDir  : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc
#   userName    : afcarrol
#   profile     : conda
#   configFiles : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc/nextflow.config
#
# Input/output options
#   input       : chr1_test.csv
# ...

# %%
# SPARK full test
/u/project/pasaniuc/afcarrol/Projects/20221017_pgsc_calc_test/nextflow run pgscatalog/pgsc_calc -r v1.2.0 \
    -profile conda \
    --input SPARK_full.csv --target_build GRCh38 \
    --scorefile PGS000327.txt.gz \
    --min_overlap 0.01
# Out:
# (plink2_env) N E X T F L O W  ~  version 22.10.1
# Launching `https://github.com/pgscatalog/pgsc_calc` [sad_curran] DSL2 - revision: 7e11510b93 [v1.2.0]
#
#
# ------------------------------------------------------
#   pgscatalog/pgsc_calc v1.2.0
# ------------------------------------------------------
# Core Nextflow options
#   revision    : v1.2.0
#   runName     : sad_curran
#   launchDir   : /u/project/pasaniuc/afcarrol/Projects/20221020_pgs_calc_autism
#   workDir     : /u/project/pasaniuc/afcarrol/Projects/20221020_pgs_calc_autism/work
#   projectDir  : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc
#   userName    : afcarrol
#   profile     : conda
#   configFiles : /u/home/a/afcarrol/.nextflow/assets/pgscatalog/pgsc_calc/nextflow.config
#
# Input/output options
#   input       : SPARK_full.csv
#   scorefile   : PGS000327.txt.gz
#   pgs_id      : null
#   pgp_id      : null
#   trait_efo   : null
#   target_build: GRCh38
#
# Variant Matching QC & Filtering
# ...

# %%
cat .command.out
# Out:
# cat .command.out
# cat: .command.out: No such file or directory
# (plink2_env)
# : 1

# %%
pwd
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20221020_pgsc_calc_autism

# %%
cat chr1_test.csv
# Out:
# cat chr1_test.csv
# sampleset,vcf_path,bfile_path,pfile_path,chrom
# SPARK,,,/u/project/geschwind/shared/GenomicDatasets-processed/ACE-ANALYSIS/freeze0/SPARK/imputed/chr1,1(plink2_env)
# : 1

# %%
ls /u/home/a/afcarrol/project-pasaniuc/vcf_trimmed/zipped
# Out:
# zippedhome/a/afcarrol/project-pasaniuc/vcf_trimmed/
# chr10.vcf.gz  chr15.vcf.gz  chr1.vcf.gz   chr3.vcf.gz  chr8.vcf.gz
# chr11.vcf.gz  chr16.vcf.gz  chr20.vcf.gz  chr4.vcf.gz  chr9.vcf.gz
# chr12.vcf.gz  chr17.vcf.gz  chr21.vcf.gz  chr5.vcf.gz
# chr13.vcf.gz  chr18.vcf.gz  chr22.vcf.gz  chr6.vcf.gz
# chr14.vcf.gz  chr19.vcf.gz  chr2.vcf.gz   chr7.vcf.gz
# (plink2_env)
# : 1

# %%
cat chr1_test_vcf.csv
# Out:
# cat chr1_test_vcf.csv
# sampleset,vcf_path,bfile_path,pfile_path,chrom
# vcf_test,/u/home/a/afcarrol/project-pasaniuc/vcf_trimmed/zipped/chr1,,,1(plink2_env)
# : 1

# %%
/u/project/pasaniuc/afcarrol/Projects/20221017_pgs_calc_test/nextflow run pgscatalog/pgsc_calc \
    -profile conda \
    --input chr1_test_vcf.csv --target_build GRCh37 \
    --accession PGS000327
# Out:
# calc_test/nextflow run pgscatalog/pgsc_calc \7_pgs_
#     -profile conda \
#     --input chr1_test_vcf.csv --target_build GRCh37 \
#     --accession PGS000327
# N E X T F L O W  ~  version 22.10.0
# Launching `https://github.com/pgscatalog/pgsc_calc` [reverent_pike] DSL2 - revision: 6f3f04296d [master]
#
# WARN: Found unexpected parameters:
# * --target_build: GRCh37
# - Ignore this warning: params.schema_ignore_params = "target_build"
#
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   pgscatalog/pgsc_calc v0.1.2dev
# ------------------------------------------------------
# Core Nextflow options
#   revision    : master
#   runName     : reverent_pike
# ...
