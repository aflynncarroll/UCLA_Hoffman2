# %%
module load plink

# %%
plink --bfile SPARK_hm3_subset --keep partial_score_indv.txt --make-bed --out just_ancestry_partial_indv/SPARK_hm3_anc_part_pop
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to just_ancestry_partial_indv/SPARK_hm3_anc_part_pop.log.
# Options in effect:
#   --bfile SPARK_hm3_subset
#   --keep partial_score_indv.txt
#   --make-bed
#   --out just_ancestry_partial_indv/SPARK_hm3_anc_part_pop
#
# 64386 MB RAM detected; reserving 32193 MB for main workspace.
# 636516 variants loaded from .bim file.
# 69487 people (0 males, 0 females, 69487 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# just_ancestry_partial_indv/SPARK_hm3_anc_part_pop.nosex .
# --keep: 6852 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 6852 founders and 0 nonfounders present.
# ...

# %%
pwd
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_full_hampap3

# %%
ls
# Out:
# just_ancestry_partial_indv  SPARK_hm3_subset.fam
# partial_score_indv.txt      SPARK_hm3_subset.log
# spark_hm3_chroms.txt        SPARK_hm3_subset.nosex
# SPARK_hm3_subset.bed        subset_to_partial_indv_sh.ipynb
# SPARK_hm3_subset.bim

# %%
ls /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_full_hampap3/just_ancestry_partial_indv/
# Out:
# SPARK_hm3_anc_part_pop.bed  SPARK_hm3_anc_part_pop.log
# SPARK_hm3_anc_part_pop.bim  SPARK_hm3_anc_part_pop.nosex
# SPARK_hm3_anc_part_pop.fam
