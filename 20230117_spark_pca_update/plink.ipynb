# %%
module load plink

# %%
module load bedtools

# %%
plink --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 --bmerge 1k_ref_bed/all_chr.bed 1k_ref_bed/all_chr.bim 1k_ref_bed/all_chr.fam --extract list.snps --make-bed --out combined_bfile/1k_spark
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to combined_bfile/1k_spark.log.
# Options in effect:
#   --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6
#   --bmerge 1k_ref_bed/all_chr.bed 1k_ref_bed/all_chr.bim 1k_ref_bed/all_chr.fam
#   --extract list.snps
#   --make-bed
#   --out combined_bfile/1k_spark
#
# 257922 MB RAM detected; reserving 128961 MB for main workspace.
# 69487 people loaded from
# SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6.fam.
# 3202 people to be merged from 1k_ref_bed/all_chr.fam.
# Of these, 3202 are new, while 0 are present in the base dataset.
# 5678744 markers loaded from
# SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6.bim.
# ...

# %%
ls
# Out:
# 1k_ref_bed            list.snps      plink.ipynb  SPARK_20210118
# combined_bfile        merge_2.txt    plink.log    Untitled1.ipynb
# files_for_pca.ipynb   merge_ref.txt  plink.nosex  Untitled.ipynb
# find_union_bed.ipynb  merge.txt      REF_1KG

# %%
plink --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 --freq
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to plink.log.
# Options in effect:
#   --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6
#   --freq
#
# 192097 MB RAM detected; reserving 96048 MB for main workspace.
# 5678744 variants loaded from .bim file.
# 69487 people (0 males, 0 females, 69487 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to plink.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 69487 founders and 0 nonfounders present.
# Calculating allele frequencies... 5%

# %%
plink --bfile 1k_ref_bed/all_chr --freq
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to plink.log.
# Options in effect:
#   --bfile 1k_ref_bed/all_chr
#   --freq
#
# 192097 MB RAM detected; reserving 96048 MB for main workspace.
# 30723119 variants loaded from .bim file.
# 3202 people (1599 males, 1603 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2591 founders and 611 nonfounders present.
# Calculating allele frequencies... 2%

# %%
plink --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 --freq

# %%
plink --bfile myfile1 --merge-list all_my_files.txt --make-bed --out mymerged

# %%
plink --merge-list merge_2.txt --make-bed --out combined_bfile/all_chr_1k_spark
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to combined_bfile/all_chr_1k_spark.log.
# Options in effect:
#   --make-bed
#   --merge-list merge_2.txt
#   --out combined_bfile/all_chr_1k_spark
#
# 64386 MB RAM detected; reserving 32193 MB for main workspace.
# Allocated 18108 MB successfully, after larger attempt(s) failed.
# ...
# 5556702 more same-position warnings: see log file.
# Performing 58-pass merge (72689 people, 630758/36401863 variants per pass).
# Pass 1 complete.
# Pass 2 complete.
# Pass 3 complete.
# Pass 4 complete.
# Pass 5 complete.
# Pass 6 complete.
# Pass 7 complete.
# Pass 8 complete.
# Pass 9 complete.

# %%
plink --help --pmerge-list
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
#
# --merge <.ped filename> <.map filename>
# --merge <text fileset prefix>
# --bmerge <.bed filename> <.bim filename> <.fam filename>
# --bmerge <binary fileset prefix>
#   Merge the given fileset with the initially loaded fileset, writing the
#   result to <output prefix>.bed + .bim + .fam.  (It is no longer necessary to
#   simultaneously specify --make-bed.)
# --merge-list <filename>
#   Merge all filesets named in the text file with the reference fileset, if
#   one was specified.  (However, this can also be used *without* a reference;
#   in that case, the newly created fileset is then treated as the reference by
#   most other PLINK operations.)  The text file is interpreted as follows:
#   * If a line contains only one name, it is assumed to be the prefix for a
#     binary fileset.
# ...
