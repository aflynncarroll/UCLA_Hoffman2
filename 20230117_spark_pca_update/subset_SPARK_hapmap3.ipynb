# %%
module load plink

# %%
plink --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 \
--extract hm3_snp_pos.txt \
--make-bed \
--out \
SPARK_full_hampap3/SPARK_hm3_subset; \

# %%
plink --merge-list SPARK_full_hampap3/spark_hm3_chroms.txt --make-bed --out SPARK_full_hampap3/SPARK_hm3_subset
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to SPARK_full_hampap3/SPARK_hm3_subset.log.
# Options in effect:
#   --make-bed
#   --merge-list SPARK_full_hampap3/spark_hm3_chroms.txt
#   --out SPARK_full_hampap3/SPARK_hm3_subset
#
# 64386 MB RAM detected; reserving 32193 MB for main workspace.
# Performing single-pass merge (69487 people, 636516 variants).
# Merged fileset written to SPARK_full_hampap3/SPARK_hm3_subset-merge.bed +
# SPARK_full_hampap3/SPARK_hm3_subset-merge.bim +
# SPARK_full_hampap3/SPARK_hm3_subset-merge.fam .
# 636516 variants loaded from .bim file.
# 69487 people (0 males, 0 females, 69487 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to SPARK_full_hampap3/SPARK_hm3_subset.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 69487 founders and 0 nonfounders present.
# ...

# %%
ls SPARK_full_hampap3
# Out:
# spark_hm3_chroms.txt  SPARK_hm3_subset.bim  SPARK_hm3_subset.log
# SPARK_hm3_subset.bed  SPARK_hm3_subset.fam  SPARK_hm3_subset.nosex

# %%
/u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_full_hampap3/SPARK_hm3_subset

# %%
pwd
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update

# %%
ls
# Out:
# 1k_ref_bed                    merge_2.txt    SPARK_20210118
# combined_bfile                merge_ref.txt  SPARK_bed_by_chrom
# files_for_pca.ipynb           merge.txt      SPARK_full_hampap3
# find_union_bed.ipynb          misc           split_spark_chr.ipynb
# hapmap3_var_extract_py.ipynb  plink.ipynb    split_spark_chrom.sh
# hm3_snp_pos.txt               plink.log      subset_SPARK_hapmap3.ipynb
# list.snps                     plink.nosex    Untitled1.ipynb
# map.rds                       REF_1KG        Untitled.ipynb
