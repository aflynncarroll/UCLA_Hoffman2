# %%
module load plink

# %%
module load bedtools

# %%
plink --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 \
--split-x chromosomes \
--extract list.snps \
--make-bed \
--out SPARK_bed_by_chrom/SPARK_genos
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to SPARK_bed_by_chrom/SPARK_genos.log.
# Options in effect:
#   --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6
#   --extract list.snps
#   --make-bed
#   --out SPARK_bed_by_chrom/SPARK_genos
#   --split-x chromosomes
#
# Error: Unrecognized --split-x build code 'chromosomes'.
# For more information, try "plink --help <flag name>" or "plink --help | more".
# : 5

# %%
--extract hm3_snp_pos.txt \

# %%
plink --help split-x
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
#
# --split-x <bp1> <bp2> ['no-fail']
# --split-x <build> ['no-fail'] :
#   Changes chromosome code of all chrX variants with bp position <= bp1 or >=
#   bp2 to XY.  The following build codes are supported as shorthand:
#   * 'b36'/'hg18' = NCBI 36, 2709521/154584237
#   * 'b37'/'hg19' = GRCh37, 2699520/154931044
#   * 'b38'/'hg38' = GRCh38, 2781479/155701383
#   By default, PLINK errors out when no variants would be affected by
#   --split-x; the 'no-fail' modifier (useful in scripts) overrides this.
# --merge-x ['no-fail'] : Merge XY chromosome back with X.

# %%
for chr in {1..22}; do \
plink --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 \
--chr $chr \
--make-bed \
--extract list.snps \
--out \
SPARK_bed_by_chrom/SPARK_genos_chr${chr}; \
done
# Out:
# Calculating allele frequencies... 2%
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to SPARK_bed_by_chrom/SPARK_genos_chr2.log.
# Options in effect:
#   --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6
#   --chr 2
#   --make-bed
#   --out SPARK_bed_by_chrom/SPARK_genos_chr2
#
# 64386 MB RAM detected; reserving 32193 MB for main workspace.
# 471733 out of 5678744 variants loaded from .bim file.
# 69487 people (0 males, 0 females, 69487 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to SPARK_bed_by_chrom/SPARK_genos_chr2.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 69487 founders and 0 nonfounders present.
# ...
