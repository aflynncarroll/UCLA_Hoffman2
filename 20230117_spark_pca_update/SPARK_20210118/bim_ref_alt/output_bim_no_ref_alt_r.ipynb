# %%
map2 = read.delim("SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6.bim", header=F, quote="")

# %%
paste(map2$V1[1], map2$V4[1], sep= ":")
# Out:
# [1] "1:802843"

# %%
map2$V2 <- paste(map2$V1, map2$V4, sep= ":")

# %%
write.table(map2, file="../SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6.bim", sep="\t", col.names=F, row.names=F, quote=F )
