# %%
. /u/local/Modules/default/init/modules.sh
module load plink

# %%
pwd
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update

# %%
ls
# Out:
# 1k_ref_bed                    plink.log
# combined_bfile                plink.nosex
# files_for_pca.ipynb           REF_1KG
# find_union_bed.ipynb          SPARK_20210118
# hapmap3_var_extract_py.ipynb  SPARK_bed_by_chrom
# hm3_snp_pos_chr.txt           SPARK_chrom_hapmap3
# hm3_snp_pos.txt               SPARK_full_hampap3
# list.snps                     SPARK_pgen_by_chrom
# map.rds                       split_spark_chr.ipynb
# merge_2.txt                   split_spark_chrom.sh
# merge_ref.txt                 split_spark_hapmap_chrom.ipynb
# merge.txt                     subset_SPARK_hapmap3.ipynb
# misc                          Untitled1.ipynb
# plink.ipynb                   Untitled.ipynb

# %%
ls "/u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_full_hampap3"
# Out:
# just_ancestry_partial_indv  SPARK_hm3_subset.fam
# partial_score_indv.txt      SPARK_hm3_subset.log
# spark_hm3_chroms.txt        SPARK_hm3_subset.nosex
# SPARK_hm3_subset.bed        subset_to_partial_indv_sh.ipynb
# SPARK_hm3_subset.bim

# %%
# Define input and output file prefixes
input_prefix="/u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_full_hampap3/SPARK_hm3_subset"
output_prefix="/u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_chrom_hapmap3/SPARK_hm3"
# Out:
# Calculating allele frequencies... 101112131415%
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_chrom_hapmap3_chr10.log.
# Options in effect:
#   --bfile /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_full_hampap3/SPARK_hm3_subset
#   --chr 10
#   --make-bed
#   --out /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_chrom_hapmap3_chr10
#
# 193121 MB RAM detected; reserving 96560 MB for main workspace.
# 34320 out of 636516 variants loaded from .bim file.
# 69487 people (0 males, 0 females, 69487 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_chrom_hapmap3_chr10.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# ...

# %%
# Loop over chromosomes 1 to 22
for chr in {1..22}; do
    # Split BED files by chromosome
    plink --bfile ${input_prefix} --chr $chr --make-bed --out ${output_prefix}_chr$chr
done
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_chrom_hapmap3_chr1.log.
# Options in effect:
#   --bfile /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_full_hampap3/SPARK_hm3_subset
#   --chr 1
#   --make-bed
#   --out /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_chrom_hapmap3_chr1
#
# 193121 MB RAM detected; reserving 96560 MB for main workspace.
# 52880 out of 636516 variants loaded from .bim file.
# 69487 people (0 males, 0 females, 69487 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/SPARK_chrom_hapmap3_chr1.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 69487 founders and 0 nonfounders present.
# ...
