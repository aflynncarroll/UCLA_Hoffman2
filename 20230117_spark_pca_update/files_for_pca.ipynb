# %%
pwd
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update

# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3

# %%
pip install --upgrade plink2
# Out:
# ERROR: Could not find a version that satisfies the requirement plink2 (from versions: none)
# ERROR: No matching distribution found for plink2
# (plink2_env)
# : 1

# %%
lsmod
# Out:
# Module                  Size  Used by
# wekafsio            70036443  1
# wekafsgw               28603  4 wekafsio
# uio_pci_generic        12685  0
# igb_uio                13506  0
# uio                    19338  2 uio_pci_generic,igb_uio
# squashfs               47827  7
# xfs                  1014152  2
# libcrc32c              12644  1 xfs
# loop                   28072  18
# nfsv3                  43720  6
# nfs_acl                12837  1 nfsv3
# nfs                   270197  12 nfsv3
# lockd                  98048  2 nfs,nfsv3
# grace                  13515  1 lockd
# fscache                64980  1 nfs
# dm_mirror              22326  0
# dm_region_hash         20813  1 dm_mirror
# dm_log                 18411  2 dm_region_hash,dm_mirror
# dm_mod                128595  2 dm_log,dm_mirror
# skx_edac               18293  0
# nfit                   59735  1 skx_edac
# libnvdimm             163620  1 nfit
# intel_powerclamp       14451  0
# coretemp               13444  0
# ...

# %%
conda -V
# Out:
# conda 4.9.2
# (plink2_env)
# : 1

# %%
conda install plink
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
#
# ResolvePackageNotFound:
#   - python=3.1
#
# (plink2_env)
# : 1

# %%
conda list --name base conda
# Out:
# # packages in environment at /u/local/apps/anaconda3/2020.11:
# #
# # Name                    Version                   Build  Channel
# anaconda                  2020.11                  py38_0
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        1.10.0                   py38_0
# anaconda-project          0.8.4                      py_0
# conda                     4.9.2            py38h06a4308_0
# conda-build               3.20.5                   py38_1
# conda-env                 2.6.0                         1
# conda-package-handling    1.7.2            py38h03888b9_0
# conda-verify              3.4.2                      py_1
# (plink2_env)
# : 1

# %%
#conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /u/local/apps/anaconda3/2020.11
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be UPDATED:
#
#   backports.functoo~                             1.6.1-py_0 --> 1.6.4-pyhd3eb1b0_0
#
# The following packages will be DOWNGRADED:
#
#   backports.tempfile                               1.0-py_1 --> 1.0-pyhd3eb1b0_1
#   xmltodict                                     0.12.0-py_0 --> 0.12.0-pyhd3eb1b0_0
#
#
# Proceed ([y]/n)?
# CondaSystemExit:
# Operation aborted.  Exiting.
#
# (plink2_env)

# %%
conda activate plink2_env
# Out:
# (plink2_env)
# : 1

# %%
conda install -c bioconda plink
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
#
# ResolvePackageNotFound:
#   - python=3.1
#
# (plink2_env)
# : 1

# %%
python3 --version
# Out:
# Python 3.11.0
# (plink2_env)
# : 1

# %%
conda info --envs
# Out:
# # conda environments:
# #
# ldsc                     /u/home/a/afcarrol/.conda/envs/ldsc
# myconda                  /u/home/a/afcarrol/.conda/envs/myconda
# plink2_env            *  /u/home/a/afcarrol/.conda/envs/plink2_env
#                          /u/home/a/afcarrol/work/conda/env-47b87cd380e598581ce75ba1c0426bca
#                          /u/home/a/afcarrol/work/conda/env-827c9f0b159ed30bc47c1e24ef559fba
# base                     /u/local/apps/anaconda3/2020.11
# ClearMap2                /u/local/apps/anaconda3/2020.11/envs/ClearMap2
# DLC-CPU                  /u/local/apps/anaconda3/2020.11/envs/DLC-CPU
# DLC-GPU                  /u/local/apps/anaconda3/2020.11/envs/DLC-GPU
# HiC-Pro_v3.1.0           /u/local/apps/anaconda3/2020.11/envs/HiC-Pro_v3.1.0
# bwa-mem2                 /u/local/apps/anaconda3/2020.11/envs/bwa-mem2
# canu                     /u/local/apps/anaconda3/2020.11/envs/canu
# charlietest              /u/local/apps/anaconda3/2020.11/envs/charlietest
# ...

# %%
conda install -c bioconda plink2
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
#
# ResolvePackageNotFound:
#   - python=3.1
#
# (plink2_env)
# : 1

# %%
conda update plink2
# Out:
# ...
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.

# %%
conda config --append channels conda-forge
# Out:
# ...
#
# CondaError: KeyboardInterrupt
#
# (plink2_env)
# : 1

# %%
conda install python=3.1

# %%
conda update plink2
# Out:
# ...
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - python=3.1
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://conda.anaconda.org/bioconda/linux-64
#   - https://conda.anaconda.org/bioconda/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# (plink2_env)
# : 1

# %%
# what kangchen originally ran
##!/bin/bash -l
#$ -cwd
#$ -j y
#$ -l h_rt=12:00:00,h_data=32G
#$ -o ./job_out

# mkdir -p ../out/01-qc-data/joint-pca

# admix pfile-merge-indiv \
#     --pfile1 ../data/REF_1KG/pgen/all_chr \
#     --pfile2 ../out/01-qc-data/SPARK/hm3/all_chr \
#     --out ../out/01-qc-data/joint-pca/merged
    
# plink2 --bfile ../out/01-qc-data/joint-pca/merged \
#     --pca approx \
#     --out ../out/01-qc-data/joint-pca/merged_pca

# %%
cp -r /u/project/pasaniuc/kangchen/2022-ace-analysis/data/REF_1KG /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update

# %%
ls /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/REF_1KG/pgen
# Out:
# all_chr.log  all_chr.pgen  all_chr.psam  all_chr.pvar  king.cutoff.out.id
# (plink2_env)
# : 1

# %%
tree
# Out:
# .
# ├── REF_1KG
# │   ├── metadata
# │   │   ├── full_sample.tsv
# │   │   ├── genetic_map
# │   │   │   ├── chr10.tsv
# │   │   │   ├── chr11.tsv
# │   │   │   ├── chr12.tsv
# │   │   │   ├── chr13.tsv
# │   │   │   ├── chr14.tsv
# │   │   │   ├── chr15.tsv
# │   │   │   ├── chr16.tsv
# │   │   │   ├── chr17.tsv
# │   │   │   ├── chr18.tsv
# │   │   │   ├── chr19.tsv
# │   │   │   ├── chr1.tsv
# │   │   │   ├── chr20.tsv
# │   │   │   ├── chr21.tsv
# │   │   │   ├── chr22.tsv
# │   │   │   ├── chr2.tsv
# │   │   │   ├── chr3.tsv
# │   │   │   ├── chr4.tsv
# │   │   │   ├── chr5.tsv
# │   │   │   ├── chr6.tsv
# │   │   │   ├── chr7.tsv
# │   │   │   ├── chr8.tsv
# │   │   │   └── chr9.tsv
# │   │   └── unrelated_sample.tsv
# │   ├── pgen
# │   │   ├── all_chr.log
# │   │   ├── all_chr.pgen
# │   │   ├── all_chr.psam
# │   │   ├── all_chr.pvar
# │   │   └── king.cutoff.out.id
# │   └── vcf
# │       ├── chr10.log
# │       ├── chr10.vcf.gz
# │       ├── chr10.vcf.gz.tbi
# ...

# %%
mkdir SPARK_20210118

# %%
ls
# Out:
# REF_1KG  SPARK_20210118  Untitled.ipynb

# %%
cp /u/home/j/jbwillia/project-geschwind/Practice_Analysis/SPARK_ACE_GWAS_PRS/SPARK_PLINK/* SPARK_20210118
# Out:
# cp: omitting directory ‘/u/home/j/jbwillia/project-geschwind/Practice_Analysis/SPARK_ACE_GWAS_PRS/SPARK_PLINK/Split_by_Ancestry’
# cp: omitting directory ‘/u/home/j/jbwillia/project-geschwind/Practice_Analysis/SPARK_ACE_GWAS_PRS/SPARK_PLINK/Split_by_Chr’
# : 1

# %%
ls SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6
# Out:
# SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6.bed
# SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6.bim
# SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6.fam
# SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6.log
# (plink2_env)
# : 1

# %%
mkdir 1k_ref_bed
# Out:
# (plink2_env)
# : 1

# %%
plink2 --pfile /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/REF_1KG/pgen/all_chr --make-bed --out 1k_ref_bed/all_chr
# Out:
# PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to 1k_ref_bed/all_chr.log.
# Options in effect:
#   --make-bed
#   --out 1k_ref_bed/all_chr
#   --pfile /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/REF_1KG/pgen/all_chr
#
# Start time: Wed Jan 18 19:03:25 2023
# 64386 MiB RAM detected; reserving 32193 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 3202 samples (1603 females, 1599 males; 2591 founders) loaded from
# /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/REF_1KG/pgen/all_chr.psam.
# 30723119 variants loaded from
# /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update/REF_1KG/pgen/all_chr.pvar.
# 2 categorical phenotypes loaded.
# Writing 1k_ref_bed/all_chr.fam ... done.
# Writing 1k_ref_bed/all_chr.bim ... done.
# ...

# %%
${RFMIX} pfile-merge-indiv \
    --bfile1 1k_ref_bed/all_chr \
    --bfile2 SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 \
    --out combined_bfile/all_chr_1k_spark
# Out:
# bash: pfile-merge-indiv: command not found
# (plink2_env)
# : 1

# %%
pwd
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update
# (plink2_env)
# : 1

# %%
/u/project/pasaniuc/afcarrol/Projects/20220216_ancestry/admix-kit/admix/ pfile-merge-indiv \
    --bfile1 1k_ref_bed/all_chr \
    --bfile2 SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 \
    --out combined_bfile/all_chr_1k_spark
# Out:
# bash: /u/project/pasaniuc/afcarrol/Projects/20220216_ancestry/admix-kit/admix/: Is a directory
# (plink2_env)
# : 1

# %%
ls 1k_ref_bed
# Out:
# all_chr.bed  all_chr.bim  all_chr.fam  all_chr.log
# (plink2_env)
# : 1

# %%
pwd
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20230117_spark_pca_update
# (plink2_env)
# : 1

# %%
mkdir combined_bfile
# Out:
# (plink2_env)
# : 1

# %%
ls
# Out:
# 1k_ref_bed      files_for_pca.ipynb  merge_ref.txt  REF_1KG
# combined_bfile  merge_2.txt          merge.txt      SPARK_20210118
# (plink2_env)
# : 1

# %%
plink2 --pmerge merge.txt --make-bed --out combined_bfile/all_chr_1k_spark
# Out:
# PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to combined_bfile/all_chr_1k_spark.log.
# Options in effect:
#   --make-bed
#   --out combined_bfile/all_chr_1k_spark
#   --pmerge merge.txt
#
# Start time: Thu Jan 19 14:55:28 2023
# Error: Unrecognized flag ('--pmerge').
# For more info, try "plink2 --help <flag name>" or "plink2 --help | more".
# (plink2_env)
# : 1

# %%
plink2 --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 --pmerge-list merge_ref.txt --make-bed --out combined_bfile/all_chr_1k_spark
# Out:
# PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to combined_bfile/all_chr_1k_spark.log.
# Options in effect:
#   --bfile SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6
#   --make-bed
#   --out combined_bfile/all_chr_1k_spark
#   --pmerge-list merge_ref.txt
#
# Start time: Thu Jan 19 15:14:42 2023
# Error: Unrecognized flag ('--pmerge-list').
# For more info, try "plink2 --help <flag name>" or "plink2 --help | more".
# (plink2_env)
# : 1

# %%
plink2 --help --pmerge-list
# Out:
# PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
#
# No help entry for '--pmerge-list'.
# (plink2_env)
# : 1

# %%
plink2 --pmerge-list merge_2.txt --make-bed --out combined_bfile/all_chr_1k_spark
# Out:
# PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to combined_bfile/all_chr_1k_spark.log.
# Options in effect:
#   --make-bed
#   --out combined_bfile/all_chr_1k_spark
#   --pmerge-list merge_2.txt
#
# Start time: Fri Jan 20 11:18:35 2023
# Error: Unrecognized flag ('--pmerge-list').
# For more info, try "plink2 --help <flag name>" or "plink2 --help | more".
# (plink2_env)
# : 1

# %%
plink2 --help --pmerge-list
# Out:
# PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
#
# No help entry for '--pmerge-list'.
# (plink2_env)
# : 1

# %%
plink2 --bfile1 1k_ref_bed/all_chr --bfile2 SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6 --make-bed --out combined_bfile/all_chr_1k_spark
# Out:
# PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to combined_bfile/all_chr_1k_spark.log.
# Options in effect:
#   --bfile1 1k_ref_bed/all_chr
#   --bfile2 SPARK_20210118/SPARKiwes_TopMed_chr1.22_rsID.MikeDB_SPARKdb155_rm.sexmismatch.49.maf0.01.geno0.05.hwe1e6
#   --make-bed
#   --out combined_bfile/all_chr_1k_spark
#
# Start time: Wed Jan 18 19:34:51 2023
# Error: Unrecognized flag ('--bfile1').
# For more info, try "plink2 --help <flag name>" or "plink2 --help | more".
# (plink2_env)
# : 1
