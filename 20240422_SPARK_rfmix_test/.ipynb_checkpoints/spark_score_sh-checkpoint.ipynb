# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3
#120G

# %%
ls /u/project/geschwind/shared/GenomicDatasets-processed/ACE-ANALYSIS/freeze0/SPARK/hm3/
# Out:
# all_chr.log         chr12.pgen  chr16.pgen  chr1.pgen   chr2.pgen  chr6.pgen
# all_chr-merge.pgen  chr12.psam  chr16.psam  chr1.psam   chr2.psam  chr6.psam
# all_chr-merge.psam  chr12.pvar  chr16.pvar  chr1.pvar   chr2.pvar  chr6.pvar
# all_chr-merge.pvar  chr13.log   chr17.log   chr20.log   chr3.log   chr7.log
# all_chr.pgen        chr13.pgen  chr17.pgen  chr20.pgen  chr3.pgen  chr7.pgen
# all_chr.psam        chr13.psam  chr17.psam  chr20.psam  chr3.psam  chr7.psam
# all_chr.pvar        chr13.pvar  chr17.pvar  chr20.pvar  chr3.pvar  chr7.pvar
# chr10.log           chr14.log   chr18.log   chr21.log   chr4.log   chr8.log
# chr10.pgen          chr14.pgen  chr18.pgen  chr21.pgen  chr4.pgen  chr8.pgen
# chr10.psam          chr14.psam  chr18.psam  chr21.psam  chr4.psam  chr8.psam
# chr10.pvar          chr14.pvar  chr18.pvar  chr21.pvar  chr4.pvar  chr8.pvar
# chr11.log           chr15.log   chr19.log   chr22.log   chr5.log   chr9.log
# ...

# %%
for chrom in {1..22}
do

pfile=/u/project/geschwind/shared/GenomicDatasets-processed/ACE-ANALYSIS/freeze0/SPARK/hm3/chr${chrom}
rfmix_msp=/u/home/a/afcarrol/project-pasaniuc/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr${chrom}.msp.tsv
out_prefix=/u/project/geschwind/shared/GenomicDatasets-processed/ACE-ANALYSIS/freeze0/SPARK/hm3/chr${chrom}.lanc


admix lanc-convert \
    --pfile ${pfile} \
    --rfmix ${rfmix_msp} \
    --out ${out_prefix}           

done
# Out:
# 2024-05-10 12:54.37 [info     ] Received parameters:
# lanc-convert
#   --pfile=/u/project/geschwind/shared/GenomicDatasets-processed/ACE-ANALYSIS/freeze0/SPARK/hm3/chr1
#   --out=/u/project/geschwind/shared/GenomicDatasets-processed/ACE-ANALYSIS/freeze0/SPARK/hm3/chr1.lanc
#   --rfmix=/u/home/a/afcarrol/project-pasaniuc/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr1.msp.tsv
#   --raw=None
# 2024-05-10 12:54.38 [info     ] Reading rfmix file: /u/home/a/afcarrol/project-pasaniuc/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr1.msp.tsv

# %%
for chrom in {1..22}
do
pfile=/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr${chrom}
weights=/u/home/a/afcarrol/project-pasaniuc/Projects/20240229_ace_partial_pgs/grove_hg19_asd.tsv
out_prefix=/u/home/a/afcarrol/project-pasaniuc/Projects/20240423_ace_partial_hm3/part_pgs/chr${chrom}

admix calc-partial-pgs \
    --plink-path ${pfile}.pgen \
    --weights-path ${weights} \
    --dset-build 'hg38->hg19' \
    --out ${out_prefix}

done
