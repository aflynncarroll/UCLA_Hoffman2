# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# Set the directory path containing the files
directory_path <- "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/"
# Initialize an empty data frame to store the results
result <- data.frame()

# %%
getwd()
# Out:
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test"

# %%
# Loop through files from ace_chr1 to ace_chr22
for (chr in 1:22) {
    

  # Construct the file path
  file_path <- paste0(directory_path, "chr", chr, ".rfmix.Q")
  print(file_path)
  # Read the data from the current file
  data <- read.table(file_path, header = F, sep = "\t")
  colnames(data) <- c("IID", "CEU", "YRI")
  # Combine the results for each ancestry (ANC1 and ANC2)
  result <- rbind(result, data)
}
# Out:
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr1.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr2.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr3.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr4.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr5.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr6.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr7.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr8.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr9.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr10.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr11.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr12.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr13.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr14.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr15.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr16.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr17.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr18.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr19.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr20.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr21.rfmix.Q"
# [1] "/u/project/pasaniuc/afcarrol/Projects/20240422_SPARK_rfmix_test/rfmix_out/chr22.rfmix.Q"

# %%
# Sum the scores across all chromosomes for each individual by ancestry
final_result <- result %>%
  group_by(IID) %>%
  summarize(
    CEU_avg = mean(CEU),
    YRI_avg = mean(YRI)
  )

# %%
head(final_result)
# Out:
#   IID                 CEU_avg   YRI_avg
# 1 SF0000003_SP0000003 0.7832200 0.2167800
# 2 SF0000017_SP0000017 0.8740418 0.1259582
# 3 SF0000027_SP0000027 0.8758268 0.1241732
# 4 SF0000027_SP0000034 0.8758264 0.1241736
# 5 SF0000027_SP0000051 0.8765914 0.1234086
# 6 SF0000027_SP0000063 0.8763118 0.1236882

# %%
range(final_result$YRI_avg)
# Out:
# [1] 0.09931727 0.60673682

# %%
range(final_result$CEU_avg)
# Out:
# [1] 0.3932632 0.9006827
