# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3
conda activate admix-env
# Out:
# (admix-env)
# : 1

# %%
pfile=/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/SPARK/SPARK_HM3/chr3
weights=/u/project/pasaniuc/aflynnca/projects/20250414_rs1452075_admx/rs1452075_score.tsv
out_prefix=/u/project/pasaniuc/aflynnca/projects/20250414_rs1452075_admx/spark_rs1452075_chr3
# Out:
# (admix-env) (admix-env) (admix-env)
# : 1

# %%
admix calc-partial-pgs \
    --plink-path ${pfile}.pgen \
    --weights-path ${weights} \
    --out ${out_prefix}
# Out:
# (admix-env) 2025-04-14 13:19:03 [info     ] Received parameters:
# calc-partial-pgs
#   --plink_path=/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/SPARK/SPARK_HM3/chr3.pgen
#   --weights_path=/u/project/pasaniuc/aflynnca/projects/20250414_rs1452075_admx/rs1452075_score.tsv
#   --out=/u/project/pasaniuc/aflynnca/projects/20250414_rs1452075_admx/spark_rs1452075_chr3
#   --ref_plink_path=None
#   --ref_pops=None
#   --weight_col=WEIGHT
#   --ref_pop_col=Population
#   --dset_build=None
#   --weights_build=None
# 2025-04-14 13:19:03 [info     ] Scoring for dataset 1/1: /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/SPARK/SPARK_HM3/chr3
# /u/home/a/aflynnca/.conda/envs/admix-env/lib/python3.11/site-packages/dapgen/_read.py:412: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   pd.read_csv(path, delim_whitespace=True, skiprows=skiprows)
# ...
