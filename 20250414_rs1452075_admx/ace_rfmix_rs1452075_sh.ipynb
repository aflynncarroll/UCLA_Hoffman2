# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3

# %%
conda activate admix-env
# Out:
# (admix-env)
# : 1

# %%
#conda

# %%
#conda install admix-kit
# Out:
# CondaError: KeyboardInterrupt

# %%
ls
# Out:
# ace_admx_indv.txt                 ace_rs1452075_genotypes.log
# ace_rfmix_rs1452075_sh.ipynb      ace_rs1452075_genotypes.raw
# ace_rs1452075_genotypes_admx.log  find_snp.sh
# ace_rs1452075_genotypes_admx.raw  rs1452075_score.tsv
# (admix-env)
# : 1

# %%
head rs1452075_score.tsv
# Out:
# (admix-env)
# : 1

# %%
head /u/project/pasaniuc/aflynnca/projects/20250414_rs1452075_admx/rs1452075_score.tsv
# Out:
# (admix-env)
# : 1

# %%
pfile=/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr3
weights=/u/project/pasaniuc/aflynnca/projects/20250414_rs1452075_admx/rs1452075_score.tsv
out_prefix=/u/project/pasaniuc/aflynnca/projects/20250414_rs1452075_admx/ace_rs1452075_chr3

admix calc-partial-pgs \
    --plink-path ${pfile}.pgen \
    --weights-path ${weights} \
    --out ${out_prefix}
# Out:
# (admix-env) (admix-env) (admix-env) (admix-env) 2025-04-14 13:09:35 [info     ] Received parameters:
# calc-partial-pgs
#   --plink_path=/u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr3.pgen
#   --weights_path=/u/project/pasaniuc/aflynnca/projects/20250414_rs1452075_admx/rs1452075_score.tsv
#   --out=/u/project/pasaniuc/aflynnca/projects/20250414_rs1452075_admx/ace_rs1452075_chr3
#   --ref_plink_path=None
#   --ref_pops=None
#   --weight_col=WEIGHT
#   --ref_pop_col=Population
#   --dset_build=None
#   --weights_build=None
# 2025-04-14 13:09:35 [info     ] Scoring for dataset 1/1: /u/project/geschwind/shared/GenomicDatasets-processed/Imputed/total_vcfs_r2_0.8/combined/hm3_filtered_pfiles/ace_hm3_chr3
# ...

# %%
pwd
# Out:
# /u/project/pasaniuc/aflynnca/projects/20250414_rs1452075_admx

# %%
ls
# Out:
# ace_admx_indv.txt                 ace_rs1452075_genotypes.log
# ace_rfmix_rs1452075_sh.ipynb      ace_rs1452075_genotypes.raw
# ace_rs1452075_genotypes_admx.log  find_snp.sh
# ace_rs1452075_genotypes_admx.raw  rs1452075_score.tsv
