# %%
#'/u/home/a/afcarrol/project-pasaniuc/Projects/20230928_pca/from_yi/onekg.chrall.phase2.qced.bed'

# %%
module load anaconda3/2023.03

# %%
conda activate plink2_env
# Out:
# EnvironmentNameNotFound: Could not find conda environment: plink2_env
# You can list all discoverable environments with `conda info --envs`.
# : 1

# %%
module load plink

# %%
plink \
  --bfile '../20230928_pca/from_yi/onekg.chrall.phase2.qced' \
  --freq \
  --out 'onekg.chrall.phase2.qced.freq'
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to onekg.chrall.phase2.qced.freq.log.
# Options in effect:
#   --bfile ../20230928_pca/from_yi/onekg.chrall.phase2.qced
#   --freq
#   --out onekg.chrall.phase2.qced.freq
#
# 192097 MB RAM detected; reserving 96048 MB for main workspace.
# 443129 variants loaded from .bim file.
# 2456 people (0 males, 0 females, 2456 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to onekg.chrall.phase2.qced.freq.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2456 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# ...

# %%
plink \
  --bfile '../20230928_pca/from_yi/onekg.chrall.phase2.qced'  \
  --hardy \
  --out 'onekg.chrall.phase2.qced.hwe'
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to onekg.chrall.phase2.qced.hwe.log.
# Options in effect:
#   --bfile ../20230928_pca/from_yi/onekg.chrall.phase2.qced
#   --hardy
#   --out onekg.chrall.phase2.qced.hwe
#
# 192097 MB RAM detected; reserving 96048 MB for main workspace.
# 443129 variants loaded from .bim file.
# 2456 people (0 males, 0 females, 2456 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to onekg.chrall.phase2.qced.hwe.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2456 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# ...
