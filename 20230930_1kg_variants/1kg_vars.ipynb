# %%
module load anaconda3/2023.03

# %%
conda activate plink2_env
# Out:
# (plink2_env)
# : 1

# %%
pwd
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20230930_1kg_variants

# %%
module load plink
# Out:
# (plink2_env)
# : 1

# %%
'/u/home/a/afcarrol/project-pasaniuc/Projects/20230928_pca/from_yi/onekg.chrall.phase2.qced

# %%
plink --bfile '/u/home/a/afcarrol/project-pasaniuc/Projects/20230928_pca/from_yi/onekg.chrall.phase2.qced' \
--out '/u/project/pasaniuc/afcarrol/Projects/20230930_1kg_variants/1kg_var' \
--list-vars ids-only
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /u/project/pasaniuc/afcarrol/Projects/20230930_1kg_variants/1kg_var.log.
# Options in effect:
#   --bfile /u/home/a/afcarrol/project-pasaniuc/Projects/20230928_pca/from_yi/onekg.chrall.phase2.qced
#   --list-vars ids-only
#   --out /u/project/pasaniuc/afcarrol/Projects/20230930_1kg_variants/1kg_var
#
# Error: Unrecognized flag ('--list-vars').
# For more information, try "plink --help <flag name>" or "plink --help | more".
# (plink2_env)
# : 1

# %%
plink --bfile '/u/home/a/afcarrol/project-pasaniuc/Projects/20230928_pca/from_yi/onekg.chrall.phase2.qced' \
--write-snplist \
--out '/u/project/pasaniuc/afcarrol/Projects/20230930_1kg_variants/1kg_var'
# Out:
# PLINK v1.90b6.24 64-bit (6 Jun 2021)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /u/project/pasaniuc/afcarrol/Projects/20230930_1kg_variants/1kg_var.log.
# Options in effect:
#   --bfile /u/home/a/afcarrol/project-pasaniuc/Projects/20230928_pca/from_yi/onekg.chrall.phase2.qced
#   --out /u/project/pasaniuc/afcarrol/Projects/20230930_1kg_variants/1kg_var
#   --write-snplist
#
# 64313 MB RAM detected; reserving 32156 MB for main workspace.
# 443129 variants loaded from .bim file.
# 2456 people (0 males, 0 females, 2456 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /u/project/pasaniuc/afcarrol/Projects/20230930_1kg_variants/1kg_var.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2456 founders and 0 nonfounders present.
# ...
