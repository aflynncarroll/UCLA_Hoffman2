# %%
. /u/local/Modules/default/init/modules.sh
module load anaconda3/2020.11

# %%
conda config --add channels defaults
conda config --add channels bioconda
conda config --add channels conda-forge
conda config --set channel_priority strict
# Out:
# conda config --add channels defaults
# ...
# (plink2_env) conda config --add channels bioconda
# (plink2_env) conda config --add channels conda-forge
# ...
# (plink2_env) conda config --set channel_priority strict
# (plink2_env)
# : 1

# %%
#java -version
# Out:
# openjdk version "1.8.0_342"
# OpenJDK Runtime Environment (build 1.8.0_342-b07)
# OpenJDK 64-Bit Server VM (build 25.342-b07, mixed mode)

# %%
#module available java
# Out:
# ------------------------- /u/local/Modules/modulefiles -------------------------
# java/jdk-11.0.14  java/jre-1.7.0_45  java/jre-1.8.0_281
# >

# %%
conda activate plink2_env
# Out:
# (plink2_env)
# : 1

# %%
module load java/jdk-11.0.14
# https://www.hoffman2.idre.ucla.edu/Using-H2/Software/Software.html#java
# Out:
# (plink2_env) (plink2_env)
# : 1

# %%
wget -qO- https://get.nextflow.io | bash
# Out:
# ...
#       N E X T F L O W
#       version 22.10.0 build 5826
#       created 13-10-2022 05:44 UTC (12-10-2022 22:44 PDT)
#       cite doi:10.1038/nbt.3820
#       http://nextflow.io
#
#
# Nextflow installation completed. Please note:
# - the executable file `nextflow` has been created in the folder: /u/project/pasaniuc/afcarrol/Projects/20221017_pgs_calc_autism
# - you may complete the installation by moving it to a directory in your $PATH
#
# (plink2_env)
# : 1

# %%
chmod +x nextflow

# %%
ls
# Out:
# nextflow  pgs_calc_autism_setup.ipynb  results  work

# %%
#apt-get update
# Out:
# bash: apt-get: command not found
# : 127

# %%
 #conda install -c conda-forge docker
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - docker
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
# : 1

# %%
#/etc/*-release
# Out:
# bash: /etc/centos-release: Permission denied
# : 126

# %%
#yum install -y yum-utils
# Out:
# Loaded plugins: fastestmirror, priorities
# You need to be root to perform this command.
# : 1

# %%
#nextflow run pgscatalog/pgsc_calc -profile test,<docker/singularity/conda>
# Out:
# bash: syntax error near unexpected token `newline'
# : 2

# %%
docker search continuumio
# Out:
# docker search continuumio
# bash: docker: command not found
# (plink2_env)
# : 1

# %%
#nextflow run pgscatalog/pgsc_calc -profile test,docker
# Out:
# kertflow run pgscatalog/pgsc_calc -profile test,doc
# N E X T F L O W  ~  version 21.10.6
# Launching `pgscatalog/pgsc_calc` [grave_liskov] - revision: 6f3f04296d [master]
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   pgscatalog/pgsc_calc v0.1.2dev
# ------------------------------------------------------
# Core Nextflow options
#   revision                  : master
#   runName                   : grave_liskov
#   containerEngine           : docker
#   launchDir                 : /u/project/pasaniuc/afcarrol/Projects/20221017_pgs_calc_autism
#   workDir                   : /u/project/pasaniuc/afcarrol/Projects/20221017_pgs_calc_autism/work
# ...

# %%
 conda install -c bioconda mawk
# Out:
#  conda install -c bioconda mawk
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /u/home/a/afcarrol/.conda/envs/plink2_env
#
#   added / updated specs:
#     - mawk
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.9.24          |  py310h06a4308_0         154 KB
#     ------------------------------------------------------------
#                                            Total:         154 KB
#
# The following NEW packages will be INSTALLED:
#
#   mawk               bioconda/linux-64::mawk-1.3.4-h779adbc_4
#
# The following packages will be UPDATED:
#
# ...

# %%
java -version
# Out:
# openjdk version "1.8.0_342"
# OpenJDK Runtime Environment (build 1.8.0_342-b07)
# OpenJDK 64-Bit Server VM (build 25.342-b07, mixed mode)

# %%
module available java
# Out:
# ------------------------- /u/local/Modules/modulefiles -------------------------
# java/jdk-11.0.14  java/jre-1.7.0_45  java/jre-1.8.0_281
# >

# %%
module load java/jdk-11.0.14
# Out:
# module load java/jdk-11.0.14
# : 1

# %%
./nextflow self-update
# Out:
# ...
#       N E X T F L O W
#       version 22.10.1 build 5828
#       created 27-10-2022 16:58 UTC (09:58 PDT)
#       cite doi:10.1038/nbt.3820
#       http://nextflow.io
#
#
# Nextflow installation completed. Please note:
# - the executable file `nextflow` has been created in the folder: .
# - you may complete the installation by moving it to a directory in your $PATH

# %%
#./PGScatalog-pgsc_calc-0a6f0aa/nextflow.config run pgscatalog/pgsc_calc --help --show_hidden_params
# Out:
# sc_calc --help --show_hidden_paramsflow.config run pgscatalog/pg
# bash: ./PGScatalog-pgsc_calc-0a6f0aa/nextflow.config: Permission denied
# : 1

# %%
./nextflow pull PGScatalog/pgsc_calc
# Out:
# Checking PGScatalog/pgsc_calc ...
# Can't find git repository config file -- Repository may be corrupted: /u/home/a/afcarrol/.nextflow/assets/PGScatalog/pgsc_calc
# (plink2_env)
# : 1

# %%
./nextflow help
# Out:
# ./nextflow help
# Usage: nextflow [options] COMMAND [arg...]
#
# Options:
#   -C
#      Use the specified configuration file(s) overriding any defaults
#   -D
#      Set JVM properties
#   -bg
#      Execute nextflow in background
#   -c, -config
#      Add the specified file to configuration set
#   -config-ignore-includes
#      Disable the parsing of config includes
#   -d, -dockerize
#      Launch nextflow via Docker (experimental)
#   -h
#      Print this help
#   -log
#      Set nextflow log file path
#   -q, -quiet
#      Do not print information messages
#   -syslog
#      Send logs to syslog server (eg. localhost:514)
#   -v, -version
#      Print the program version
#
# Commands:
#   clean         Clean up project cache and work directories
#   clone         Clone a project into a folder
#   config        Print a project configuration
#   console       Launch Nextflow interactive console
#   drop          Delete the local copy of a project
# ...

# %%
./nextflow run pgscatalog/pgsc_calc --help
# Out:
# ./nextflow run pgscatalog/pgsc_calc --help
# N E X T F L O W  ~  version 22.10.1
# Launching `https://github.com/pgscatalog/pgsc_calc` [high_archimedes] DSL2 - revision: 6f3f04296d [master]
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   pgscatalog/pgsc_calc v0.1.2dev
# ------------------------------------------------------
# Typical pipeline command:
#
#   nextflow run pgscatalog/pgsc_calc --input assets/samplesheet.csv --scorefile assets/PGS001229_22.txt -profile docker
#
# Input/output options
#   --input                             [string]  Path to comma-separated file containing information about the samples (a sample sheet)
#   --format                            [string]  Format of the input [default: csv]
# ...

# %%
nextflow config pgscatalog/pgsc_calc
# Out:
# nextflow config pgscatalog/pgsc_calc
# params {
#    input = null
#    format = 'csv'
#    scorefile = null
#    accession = null
#    min_overlap = 0.75
#    outdir = './results'
#    tracedir = './results/pipeline_info'
#    publish_dir_mode = 'copy'
#    email = null
#    email_on_fail = null
#    plaintext_email = false
#    monochrome_logs = false
#    help = false
#    validate_params = true
#    show_hidden_params = false
#    schema_ignore_params = ''
#    enable_conda = false
#    singularity_pull_docker_container = false
#    custom_config_version = 'master'
#    custom_config_base = 'https://raw.githubusercontent.com/nf-core/configs/master'
#    hostnames = []
#    config_profile_description = null
#    config_profile_contact = null
#    config_profile_url = null
#    config_profile_name = null
#    max_memory = '12.GB'
#    max_cpus = 2
#    max_time = '1.h'
# }
#
# process {
#    cpus = { check_max( 1    * task.attempt, 'cpus'   ) }
# ...

# %%
./nextflow pull pgscatalog/pgsc_calc -h
# Out:
# Download or update a project
# Usage: pull [options] project name or repository url to pull
#   Options:
#     -all
#        Update all downloaded projects
#        Default: false
#     -h, -help
#        Print the command usage
#        Default: false
#     -hub
#        Service hub where the project is hosted
#     -r, -revision
#        Revision of the project to run (either a git branch, tag or commit SHA
#        number)
#     -user
#        Private repository user name
#
# (plink2_env)
# : 1

# %%
./nextflow pull pgscatalog/pgsc_calc -r v1.2.0
# Out:
# Checking pgscatalog/pgsc_calc ...
#  done - revision: 7e11510b93 [v1.2.0]
# (plink2_env)
# : 1

# %%
pip install pyyaml
# Out:
# pip install pyyaml
# ...
#      |████████████████████████████████| 682 kB 18.4 MB/s eta 0:00:01
# ...
# (plink2_env)
# : 1

# %%
conda install -c "bioconda/label/cf201901" mawk
# Out:
# conda install -c "bioconda/label/cf201901" mawk
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /u/home/a/afcarrol/.conda/envs/plink2_env
#
#   added / updated specs:
#     - mawk
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.9.24          |  py310h06a4308_0         154 KB
#     mawk-1.3.4                 |       h14c3975_2          98 KB  bioconda/label/cf201901
#     ------------------------------------------------------------
#                                            Total:         252 KB
#
# The following NEW packages will be INSTALLED:
#
#   mawk               bioconda/label/cf201901/linux-64::mawk-1.3.4-h14c3975_2
#
# ...

# %%
conda install -c bioconda mawk
# Out:
# conda install -c bioconda mawk
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /u/home/a/afcarrol/.conda/envs/plink2_env
#
#   added / updated specs:
#     - mawk
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.9.24          |  py310h06a4308_0         154 KB
#     ------------------------------------------------------------
#                                            Total:         154 KB
#
# The following NEW packages will be INSTALLED:
#
#   mawk               bioconda/linux-64::mawk-1.3.4-h779adbc_4
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.4.26-h06a4308_0 --> 2022.07.19-h06a4308_0
# ...

# %%
conda update -n base -c defaults conda
# Out:
# conda update -n base -c defaults conda
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /u/local/apps/anaconda3/2020.11
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-22.9.0               |   py38h06a4308_0         884 KB
#     ------------------------------------------------------------
#                                            Total:         884 KB
#
# The following packages will be UPDATED:
#
#   backports.functoo~                             1.6.1-py_0 --> 1.6.4-pyhd3eb1b0_0
#   conda                                4.9.2-py38h06a4308_0 --> 22.9.0-py38h06a4308_0
#
# The following packages will be DOWNGRADED:
#
#   backports.tempfile                               1.0-py_1 --> 1.0-pyhd3eb1b0_1
#   xmltodict                                     0.12.0-py_0 --> 0.12.0-pyhd3eb1b0_0
#
#
# ...

# %%
module load apptainer
# Out:
# (plink2_env)
# : 1

# %%
apptainer pull --help
# Out:
# Pull an image from a URI
#
# Usage:
#   apptainer pull [pull options...] [output file] <URI>
#
# Description:
#   The 'pull' command allows you to download or build a container from a given
#   URI. Supported URIs include:
#
#   library: Pull an image from the currently configured library
#       library://user/collection/container[:tag]
#
#   docker: Pull a Docker/OCI image from Docker Hub, or another OCI registry.
#       docker://user/image:tag
#
#   shub: Pull an image from Singularity Hub
#       shub://user/image:tag
#
#   oras: Pull a SIF image from an OCI registry that supports ORAS.
#       oras://registry/namespace/image:tag
#
#   http, https: Pull an image using the http(s?) protocol
#       https://library.sylabs.io/v1/imagefile/library/default/alpine:latest
#
# Options:
#       --arch string      architecture to pull from library (default "amd64")
#       --dir string       download images to the specific directory
# ...

# %%
./nextflow run pgscatalog/pgsc_calc -profile test,apptainer --docker-login
# Out:
# N E X T F L O W  ~  version 22.10.0
# Unknown configuration profile: 'apptainer'
# (plink2_env)
# : 1

# %%
conda create --mkdir --yes --prefix /u/project/pasaniuc/afcarrol/Projects/20221017_pgs_calc_autism/work/conda/env-4d5473a9e7d69b51c0066e96a07e373f conda-forge::r-tidyverse=1.3.1

# %%
pwd
# Out:
# /u/project/pasaniuc/afcarrol/Projects/20221017_pgs_calc_test
