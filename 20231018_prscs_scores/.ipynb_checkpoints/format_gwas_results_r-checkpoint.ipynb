# %%
library(dplyr)
library(biomaRt)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
getwd()
# Out:
# [1] "/u/project/pasaniuc/afcarrol/Projects/20231018_prscs_scores"

# %%
getwd()
# Out:
# [1] "/u/project/pasaniuc/afcarrol/Projects/20231018_prscs_scores"

# %%
raw_grove <- read.table('/u/project/pasaniuc/afcarrol/Projects/20231018_prscs_scores/iPSYCH-PGC_ASD_Nov2017.txt', sep="\t")

# %%
head(raw_grove)
# Out:
#   V1  V2         V3        V4 V5 V6    V7      V8     V9
# 1 CHR SNP        BP        A1 A2 INFO  OR      SE     P
# 2 8   rs62513865 101592213 T  C  0.949 1.00652 0.027  0.8086
# 3 8   rs79643588 106973048 A  G  0.997 1.01786 0.024  0.4606
# 4 8   rs17396518 108690829 T  G  0.987 0.96127 0.014  0.004647
# 5 8   rs983166   108681675 A  C  0.998 0.97990 0.0139 0.1452
# 6 8   rs28842593 103044620 T  C  0.857 0.99591 0.0203 0.8415

# %%
# Set the column names using the values from the first row
colnames(raw_grove) <- unlist(raw_grove[1,])

# Remove the first row (optional if you don't need it anymore)
raw_grove <- raw_grove[-1,]

# %%
head(raw_grove)
# Out:
#   CHR SNP        BP        A1 A2 INFO  OR      SE     P
# 2 8   rs62513865 101592213 T  C  0.949 1.00652 0.027  0.8086
# 3 8   rs79643588 106973048 A  G  0.997 1.01786 0.024  0.4606
# 4 8   rs17396518 108690829 T  G  0.987 0.96127 0.014  0.004647
# 5 8   rs983166   108681675 A  C  0.998 0.97990 0.0139 0.1452
# 6 8   rs28842593 103044620 T  C  0.857 0.99591 0.0203 0.8415
# 7 8   rs35107696 109712249 A  AT 0.999 1.01308 0.0165 0.4302

# %%
grove_table <- raw_grove[,c("SNP", "A1", "A2", "OR", "P")]

# %%
write.table(grove_table, file = "grove_gwas.txt", sep = "\t", row.names = FALSE)

# %%
rm(grove_table, raw_grove)

# %%
raw_spark <- read.table('/u/project/geschwind/vishakha/Projects/GWAS_AFR/GWAS_SAIGE_AFR_11M_var/SAIGE_RESULT/SPARK_AA_marker_chr1-22_vcf.txt', sep="\t")

# %%
head(raw_spark)
# Out:
#   V1  V2     V3          V4      V5      V6         V7         V8
# 1 CHR POS    MarkerID    Allele1 Allele2 AC_Allele2 AF_Allele2 MissingRate
# 2 1   858952 rs12127425  G       A       1064       0.113578   0
# 3 1   859842 rs12131377  C       G       487        0.0519855  0
# 4 1   863421 rs12132517  G       A       482        0.0514518  0
# 5 1   864119 rs147634896 T       C       485        0.051772   0
# 6 1   866281 rs12132974  C       T       440        0.0469684  0
#   V9        V10      ⋯ V14          V15    V16       V17       V18    V19
# 1 BETA      SE       ⋯ p.value.NA   Is.SPA AF_case   AF_ctrl   N_case N_ctrl
# 2 0.0332094 0.122293 ⋯ 7.859630E-01 false  0.11013   0.117902  2606   2078
# 3 0.0816997 0.174133 ⋯ 6.389405E-01 false  0.0519954 0.0519731 2606   2078
# 4 0.0954879 0.175393 ⋯ 5.861508E-01 false  0.0514198 0.0514918 2606   2078
# 5 0.0778062 0.175215 ⋯ 6.569981E-01 false  0.0518035 0.0517324 2606   2078
# ...

# %%
# Set the column names using the values from the first row
colnames(raw_spark) <- unlist(raw_spark[1,])

# Remove the first row (optional if you don't need it anymore)
raw_spark <- raw_spark[-1,]

# %%
head(raw_spark)
# Out:
#   CHR POS    MarkerID    Allele1 Allele2 AC_Allele2 AF_Allele2 MissingRate
# 2 1   858952 rs12127425  G       A       1064       0.113578   0
# 3 1   859842 rs12131377  C       G       487        0.0519855  0
# 4 1   863421 rs12132517  G       A       482        0.0514518  0
# 5 1   864119 rs147634896 T       C       485        0.051772   0
# 6 1   866281 rs12132974  C       T       440        0.0469684  0
# 7 1   866300 rs12134490  A       C       440        0.0469684  0
#   BETA      SE       ⋯ p.value.NA   Is.SPA AF_case   AF_ctrl   N_case N_ctrl
# 2 0.0332094 0.122293 ⋯ 7.859630E-01 false  0.11013   0.117902  2606   2078
# 3 0.0816997 0.174133 ⋯ 6.389405E-01 false  0.0519954 0.0519731 2606   2078
# 4 0.0954879 0.175393 ⋯ 5.861508E-01 false  0.0514198 0.0514918 2606   2078
# 5 0.0778062 0.175215 ⋯ 6.569981E-01 false  0.0518035 0.0517324 2606   2078
# 6 0.133888  0.183498 ⋯ 4.656069E-01 false  0.0477744 0.0459577 2606   2078
# ...

# %%
colnames(raw_spark)
# Out:
#  [1] "CHR"         "POS"         "MarkerID"    "Allele1"     "Allele2"
#  [6] "AC_Allele2"  "AF_Allele2"  "MissingRate" "BETA"        "SE"
# [11] "Tstat"       "var"         "p.value"     "p.value.NA"  "Is.SPA"
# [16] "AF_case"     "AF_ctrl"     "N_case"      "N_ctrl"      "N_case_hom"
# [21] "N_case_het"  "N_ctrl_hom"  "N_ctrl_het"

# %%
spark_chr_pos <- raw_spark[,c("CHR", "POS")]

# %%
head(spark_chr_pos)
# Out:
#   CHR POS
# 2 1   858952
# 3 1   859842
# 4 1   863421
# 5 1   864119
# 6 1   866281
# 7 1   866300

# %%
write.table(spark_chr_pos, file = "spark_gwas_cp.txt", sep = "\t", row.names = FALSE, col.names = FALSE)

# %%
spark_table <- raw_spark[,c("MarkerID", "Allele1", "Allele2", "BETA", "p.value")]

# %%
head(spark_table)
# Out:
#   MarkerID    Allele1 Allele2 BETA      p.value
# 2 rs12127425  G       A       0.0332094 7.859630E-01
# 3 rs12131377  C       G       0.0816997 6.389405E-01
# 4 rs12132517  G       A       0.0954879 5.861508E-01
# 5 rs147634896 T       C       0.0778062 6.569981E-01
# 6 rs12132974  C       T       0.133888  4.656069E-01
# 7 rs12134490  A       C       0.133888  4.656069E-01

# %%
colnames(spark_table) <- c("SNP", "A1", "A2", "BETA", "P")

# %%
head(spark_table)
# Out:
# Error in head(spark_table): object 'spark_table' not found
# Traceback:
#
# 1. head(spark_table)

# %%
write.table(spark_table, file = "spark_gwas.txt", sep = "\t", row.names = FALSE)

# %%
rm(raw_spark)

# %%
spark_table <- read.table("spark_gwas.txt")

# %%
# Set the column names using the values from the first row
colnames(spark_table) <- unlist(spark_table[1,])

# Remove the first row (optional if you don't need it anymore)
spark_table <- spark_table[-1,]

# %%
head(spark_table)
# Out:
#   SNP         A1 A2 BETA      P
# 2 rs12127425  G  A  0.0332094 7.859630E-01
# 3 rs12131377  C  G  0.0816997 6.389405E-01
# 4 rs12132517  G  A  0.0954879 5.861508E-01
# 5 rs147634896 T  C  0.0778062 6.569981E-01
# 6 rs12132974  C  T  0.133888  4.656069E-01
# 7 rs12134490  A  C  0.133888  4.656069E-01

# %%
# Set the Mart and dataset for hg19
#ensembl <- useEnsembl(biomart = "ENSEMBL_MART_ENSEMBL", dataset = "hsapiens_gene_ensembl", host = 'www.ensembl.org', version = "GRCh37")

# Define a list of rsIDs
# Out:
# Possible SSL connectivity problems detected.
# Please report this issue at https://github.com/grimbough/biomaRt/issues
# Error in curl::curl_fetch_memory(url, handle = handle) :
#   Peer certificate cannot be authenticated with given CA certificates: [uswest.ensembl.org] Peer's Certificate has expired.

# %%
ensembl <- useEnsembl(biomart = "ENSEMBL_MART_ENSEMBL", dataset = "hsapiens_gene_ensembl", host = 'useast.ensembl.org', version = "GRCh37")

# %%
rsids <- spark_table$SNP

# %%
snpmart = useEnsembl(biomart = "snp", dataset="hsapiens_snp", version = "GRCh37")

# Get the chromosome, position, reference allele, and alternate allele for each rsID
snp_info <- getBM(attributes = c("refsnp_id", "chr_name", "chrom_start", "allele", "minor_allele"),
                  filters = "snp_filter", values = rsids, mart = snpmart)
# Out:
# Batch submitting query [-------------------------------]   0% eta:  5d
#
# Batch submitting query [-------------------------------]   0% eta:  4d
#
# Batch submitting query [-------------------------------]   1% eta:  4d

# %%
att <- listAttributes(ensembl)

# %%
View(att)
# Out:
#      name
# 1    ensembl_gene_id
# 2    ensembl_gene_id_version
# 3    ensembl_transcript_id
# 4    ensembl_transcript_id_version
# 5    ensembl_peptide_id
# 6    ensembl_peptide_id_version
# 7    ensembl_exon_id
# 8    description
# 9    chromosome_name
# 10   start_position
# 11   end_position
# 12   strand
# 13   band
# 14   transcript_start
# 15   transcript_end
# 16   transcription_start_site
# 17   transcript_length
# 18   transcript_tsl
# 19   transcript_gencode_basic
# 20   transcript_appris
# 21   transcript_is_canonical
# 22   transcript_mane_select
# 23   transcript_mane_plus_clinical
# 24   external_gene_name
# 25   external_gene_source
# 26   external_transcript_name
# 27   external_transcript_source_name
# 28   transcript_count
# 29   percentage_gene_gc_content
# 30   gene_biotype
# ⋮    ⋮
# 3140 5_utr_end
# 3141 3_utr_start
# 3142 3_utr_end
# 3143 ensembl_transcript_id
# 3144 ensembl_transcript_id_version
# 3145 ensembl_peptide_id
# 3146 ensembl_peptide_id_version
# ...

# %%
write.table(att, file = "ens_att.txt", sep = "\t", row.names = FALSE)
