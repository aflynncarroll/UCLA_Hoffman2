# %%
 pip install nb_black
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached nb_black-1.0.7.tar.gz (4.8 kB)
# ...
#      |████████████████████████████████| 1.6 MB 28.3 MB/s eta 0:00:01
# ...
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# ...
#      |████████████████████████████████| 42 kB 697 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 96 kB 5.6 MB/s s eta 0:00:01
# ...
# Using legacy 'setup.py install' for nb-black, since package 'wheel' is not installed.
# ...
#     Running setup.py install for nb-black ... done
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/u/local/apps/python/3.9.6/gcc-4.8.5/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
/u/local/apps/python/3.9.6/gcc-4.8.5/bin/python3.9 -m pip install --upgrade pip
# Out:
#   File "/tmp/ipykernel_26599/936219089.py", line 1
#     u/local/apps/python/3.9.6/gcc-4.8.5/bin/python3.9(-m, pip, install, --upgrade, pip)
#                            ^
# SyntaxError: invalid syntax

# %%
pip3 install git+https://github.com/psf/black
# Out:
#   File "/tmp/ipykernel_26599/542632317.py", line 1
#     pip3 install git+https://github.com/psf/black
#          ^
# SyntaxError: invalid syntax
# ERROR:root:Cannot parse: 1:5: pip3 install git+https://github.com/psf/black
# Traceback (most recent call last):
#   File "/u/home/a/afcarrol/.local/lib/python3.9/site-packages/lab_black.py", line 218, in format_cell
#     formatted_code = _format_code(cell)
#   File "/u/home/a/afcarrol/.local/lib/python3.9/site-packages/lab_black.py", line 29, in _format_code
#     return format_str(src_contents=code, mode=FileMode())
#   File "src/black/__init__.py", line 1079, in format_str
#   File "src/black/__init__.py", line 1089, in _format_str_once
#   File "src/black/parsing.py", line 127, in lib2to3_parse
# black.parsing.InvalidInput: Cannot parse: 1:5: pip3 install git+https://github.com/psf/black

# %%
# %load_ext nb_black

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/u/local/apps/python/3.9.6/gcc-4.8.5/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ERROR:root:Cannot parse: 1:4: pip install numpy
# Traceback (most recent call last):
#   File "/u/home/a/afcarrol/.local/lib/python3.9/site-packages/lab_black.py", line 218, in format_cell
#     formatted_code = _format_code(cell)
#   File "/u/home/a/afcarrol/.local/lib/python3.9/site-packages/lab_black.py", line 29, in _format_code
#     return format_str(src_contents=code, mode=FileMode())
#   File "src/black/__init__.py", line 1079, in format_str
#   File "src/black/__init__.py", line 1089, in _format_str_once
#   File "src/black/parsing.py", line 127, in lib2to3_parse
# ...

# %%
pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 9.9 MB 35.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 233 kB 107.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/u/local/apps/python/3.9.6/gcc-4.8.5/bin/python3.9 -m pip install --upgrade pip' command.
# ERROR:root:Cannot parse: 1:4: pip install statsmodels
# Traceback (most recent call last):
#   File "/u/home/a/afcarrol/.local/lib/python3.9/site-packages/lab_black.py", line 218, in format_cell
#     formatted_code = _format_code(cell)
#   File "/u/home/a/afcarrol/.local/lib/python3.9/site-packages/lab_black.py", line 29, in _format_code
#     return format_str(src_contents=code, mode=FileMode())
#   File "src/black/__init__.py", line 1079, in format_str
#   File "src/black/__init__.py", line 1089, in _format_str_once
# ...

# %%
pip install flake8 pytest cython numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 57 kB 3.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 62 kB 1.1 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 41 kB 219 kB/s  eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/u/local/apps/python/3.9.6/gcc-4.8.5/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cmake
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 23.7 MB 42.1 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/u/local/apps/python/3.9.6/gcc-4.8.5/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import cmake as cmake

# %%
cmake
# Out:
# <module 'cmake' from '/u/home/a/afcarrol/.local/lib/python3.9/site-packages/cmake/__init__.py'>

# %%
git clone https://github.com/KangchengHou/admix-kit
# Out:
#   File "/tmp/ipykernel_104155/2054207335.py", line 1
#     git clone https://github.com/KangchengHou/admix-kit
#         ^
# SyntaxError: invalid syntax

# %%
pip install git+https://github.com/kangchenghou/admix-kit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Cloning https://github.com/kangchenghou/admix-kit to /work/tmp/pip-req-build-mnsc7uq5
#   Running command git clone -q https://github.com/kangchenghou/admix-kit /work/tmp/pip-req-build-mnsc7uq5
#   Resolved https://github.com/kangchenghou/admix-kit to commit 3b4ca3255a2c2e6aafd1975658644594a72e145d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#   Cloning https://github.com/KangchengHou/dask-pgen.git to /work/tmp/pip-install-7i7ildjl/dask-pgen_a46239c3b4c64bc697b65dc6c4668138
#   Running command git clone -q https://github.com/KangchengHou/dask-pgen.git /work/tmp/pip-install-7i7ildjl/dask-pgen_a46239c3b4c64bc697b65dc6c4668138
#   Resolved https://github.com/KangchengHou/dask-pgen.git to commit 9fd03c5e43033969c45e69203df69a3c4be7322a
# ...

# %%
pip install -e .
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: File "setup.py" or "setup.cfg" not found. Directory cannot be installed in editable mode: /u/project/pasaniuc/afcarrol/Projects/20230228_installation
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/u/local/apps/python/3.9.6/gcc-4.8.5/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.path)
# Out:
# ['/u/project/pasaniuc/afcarrol/Projects/20230228_installation', '/u/local/apps/python/3.9.6/gcc-4.8.5/lib/python39.zip', '/u/local/apps/python/3.9.6/gcc-4.8.5/lib/python3.9', '/u/local/apps/python/3.9.6/gcc-4.8.5/lib/python3.9/lib-dynload', '', '/u/home/a/afcarrol/.local/lib/python3.9/site-packages', '/u/local/apps/python/3.9.6/gcc-4.8.5/lib/python3.9/site-packages', '/u/local/apps/python/3.9.6/gcc-4.8.5/lib/python3.9/site-packages/IPython/extensions', '/u/home/a/afcarrol/.ipython']

# %%
ls /u/home/a/afcarrol/.local/bin/
# Out:
# admix*                             maf_mean_length_ungapped_piece.py*
# aggregate_scores_in_intervals.py*  maf_percent_columns_matching.py*
# align_print_template.py*           maf_percent_identity.py*
# aws*                               maf_print_chroms.py*
# aws_bash_completer*                maf_print_scores.py*
# aws.cmd*                           maf_randomize.py*
# aws_completer*                     maf_region_coverage_by_src.py*
# aws_zsh_completer.sh*              maf_select.py*
# axt_extract_ranges.py*             maf_shuffle_columns.py*
# axt_to_fasta.py*                   maf_species_in_all_files.py*
# axt_to_lav.py*                     maf_split_by_src.py*
# axt_to_maf.py*                     maf_thread_for_species.py*
# bed_bigwig_profile.py*             maf_tile_2bit.py*
# bed_build_windows.py*              maf_tile_2.py*
# bed_complement.py*                 maf_tile.py*
# bed_count_by_interval.py*          maf_to_axt.py*
# ...

# %%
import admix

# %%
#export PYTHONPATH=$PYTHONPATH:/u/home/a/afcarrol/.local/bin
sys.path.remove("/u/home/a/afcarrol/.local/bin/admix")

# %%
pip install dapgen
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement dapgen (from versions: none)
# ERROR: No matching distribution found for dapgen
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/u/local/apps/python/3.9.6/gcc-4.8.5/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
ls /u/home/a/afcarrol/project-pasaniuc/Projects/20220216_ancestry/admix-kit
# Out:
# admix/      admix_kit.egg-info/  docs/      pyproject.toml  setup.cfg  tests/
# admix-kit/  build/               examples/  README.md       setup.py

# %%
sys.path.append("/u/home/a/afcarrol/project-pasaniuc/Projects/20220216_ancestry/admix-kit")

# %%
python -c "import sys; print('\n'.join(sys.path))"
# Out:
#   File "/tmp/ipykernel_104155/1066694186.py", line 1
#     python -c "import sys; print('\n'.join(sys.path))"
#               ^
# SyntaxError: invalid syntax

# %%
$PYTHONPATH
# Out:
#   File "/tmp/ipykernel_26599/883065976.py", line 1
#     $PYTHONPATH
#     ^
# SyntaxError: invalid syntax
# ERROR:root:Cannot parse: 1:0: $PYTHONPATH
# Traceback (most recent call last):
#   File "/u/home/a/afcarrol/.local/lib/python3.9/site-packages/lab_black.py", line 218, in format_cell
#     formatted_code = _format_code(cell)
#   File "/u/home/a/afcarrol/.local/lib/python3.9/site-packages/lab_black.py", line 29, in _format_code
#     return format_str(src_contents=code, mode=FileMode())
#   File "src/black/__init__.py", line 1079, in format_str
#   File "src/black/__init__.py", line 1089, in _format_str_once
#   File "src/black/parsing.py", line 127, in lib2to3_parse
# black.parsing.InvalidInput: Cannot parse: 1:0: $PYTHONPATH

# %%
pip list
# Out:
# Package             Version
# ------------------- ---------
# anyio               3.3.0
# argon2-cffi         20.1.0
# asciitree           0.3.3
# attrs               21.2.0
# Babel               2.9.1
# backcall            0.2.0
# bash_kernel         0.7.2
# black               23.1.0
# bleach              4.0.0
# bx-python           0.8.13
# certifi             2021.5.30
# cffi                1.14.6
# charset-normalizer  2.0.4
# click               8.1.3
# cloudpickle         2.1.0
# cmake               3.25.2
# cycler              0.10.0
# Cython              0.29.24
# dask                2022.6.1
# debugpy             1.4.1
# decorator           5.0.9
# defusedxml          0.7.1
# Deprecated          1.2.13
# entrypoints         0.3
# fasteners           0.18
# fire                0.5.0
# flake8              6.0.0
# fsspec              2022.5.0
# greenlet            1.1.2
# h5py                3.3.0
# iced                0.5.10
# idna                3.2
# ...
