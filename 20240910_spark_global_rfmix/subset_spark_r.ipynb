# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
spark_iids <- read.table("/u/project/geschwind/shared/GenomicDatasets-processed/ACE-ANALYSIS/freeze0/SPARK/imputed/chr1.psam")

# %%
head(spark_iids)
# Out:
#   V1                  V2
# 1 SF0000003_SP0000003 NA
# 2 SF0030253_SP0000006 NA
# 3 SF0031322_SP0000007 NA
# 4 SF0013567_SP0000009 NA
# 5 SF0024927_SP0000014 NA
# 6 SF0020550_SP0000015 NA

# %%
length(spark_iids$V1)
# Out:
# [1] 68316

# %%
68316/2
# Out:
# [1] 34158

# %%
length(spark_iids$V1[1:34158])
# Out:
# [1] 34158

# %%
write.table(spark_iids$V1[1:34158], "spark_ids_g1.txt", row.names = FALSE, col.names = FALSE, quote = FALSE, sep = "\t")

# %%
length(spark_iids$V1[34159:68316])
# Out:
# [1] 34158

# %%
write.table(spark_iids$V1[34159:68316], "spark_ids_g2.txt", row.names = FALSE, col.names = FALSE, quote = FALSE, sep = "\t")
