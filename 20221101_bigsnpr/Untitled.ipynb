# %%
install.packages("bigsnpr")
# Out:
# Installing package into ‘/u/home/a/afcarrol/R/x86_64-pc-linux-gnu-library-RH7/4.0.2’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘DEoptimR’, ‘triebeard’, ‘cowplot’, ‘RSpectra’, ‘doParallel’, ‘flock’, ‘parallelly’, ‘RhpcBLASctl’, ‘RcppEigen’, ‘nabor’, ‘robustbase’, ‘rngtools’, ‘iterators’, ‘urltools’, ‘ff’, ‘bigstatsr’, ‘bigassertr’, ‘bigparallelr’, ‘bigsparser’, ‘bigreadr’, ‘bigutilsr’, ‘doRNG’, ‘foreach’, ‘runonce’, ‘rmio’, ‘roptim’
