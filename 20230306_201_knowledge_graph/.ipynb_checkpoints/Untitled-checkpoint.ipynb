# %%
! pip install neo4j
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting neo4j
#   Downloading neo4j-5.6.0.tar.gz (171 kB)
#      |████████████████████████████████| 171 kB 19.7 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pytz in /u/local/apps/python/3.9.6/gcc-4.8.5/lib/python3.9/site-packages (from neo4j) (2021.1)
# Building wheels for collected packages: neo4j
#   Building wheel for neo4j (PEP 517) ... done
#   Created wheel for neo4j: filename=neo4j-5.6.0-py3-none-any.whl size=237438 sha256=c000d441423ff870151f9a05742dba2ff9f6983c0639a641ca6e78d699fd6d12
#   Stored in directory: /u/home/a/afcarrol/.cache/pip/wheels/c0/9b/d9/fdb6b67a6f6d7aef4acaefe55f339739caf09bb63e43bfb10e
# Successfully built neo4j
# Installing collected packages: neo4j
# Successfully installed neo4j-5.6.0
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/u/local/apps/python/3.9.6/gcc-4.8.5/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import json
import time
from neo4j import GraphDatabase

# %%
import pandas as pd
from neo4j import GraphDatabase
driver=GraphDatabase.driver(uri="bolt://127.0.0.1:7687",auth=("neo4j","1234"))
session=driver.session()

#driver=GraphDatabase.driver(uri="neo4j://localhost:7687",auth=("afcarroll@ucla.edu","4PrFVv2eJvNA43d"))

# %%
driver

# %%
def create_constraints(driver):
        query = ["CREATE CONSTRAINT UniqueNode1IdConstraint FOR (n1:Node1) REQUIRE n1.nodeId IS UNIQUE",\
                 "CREATE CONSTRAINT UniqueNode2IdConstraint FOR (n2:Node2) REQUIRE n2.nodeId IS UNIQUE",\
                 "CREATE CONSTRAINT UniqueNode3IdConstraint FOR (n3:Node3) REQUIRE n3.nodeId IS UNIQUE"]
        with driver.session() as session:
            for constraint in query:
                session.run(constraint)

# %%
'''UNCOMMENT AND RUN THIS CELL ONLY ONCE'''
create_constraints(driver)
# Out:
# Unable to retrieve routing information
# ---------------------------------------------------------------------------
# ServiceUnavailable                        Traceback (most recent call last)
# /tmp/ipykernel_200384/1319761676.py in <module>
#       1 '''UNCOMMENT AND RUN THIS CELL ONLY ONCE'''
# ----> 2 create_constraints(driver)
#
# /tmp/ipykernel_200384/3703363727.py in create_constraints(driver)
#       5         with driver.session() as session:
#       6             for constraint in query:
# ----> 7                 session.run(constraint)
#
# ~/.local/lib/python3.9/site-packages/neo4j/_sync/work/session.py in run(self, query, parameters, **kwargs)
#     278
#     279         if not self._connection:
# --> 280             self._connect(self._config.default_access_mode)
#     281         cx = self._connection
#     282
#
# ~/.local/lib/python3.9/site-packages/neo4j/_sync/work/session.py in _connect(self, access_mode, **access_kwargs)
#     118             access_mode = self._config.default_access_mode
#     119         try:
# --> 120             super()._connect(access_mode, **access_kwargs)
#     121         except asyncio.CancelledError:
#     122             self._handle_cancellation(message="_connect")
#
# ~/.local/lib/python3.9/site-packages/neo4j/_sync/work/workspace.py in _connect(self, access_mode, **acquire_kwargs)
#     151                 # actions within this session.
#     152                 log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 153                 self._pool.update_routing_table(
#     154                     database=self._config.database,
#     155                     imp_user=self._config.impersonated_user,
#
# ~/.local/lib/python3.9/site-packages/neo4j/_sync/io/_pool.py in update_routing_table(self, database, imp_user, bookmarks, acquisition_timeout, database_callback)
#     674             # None of the routers have been successful, so just fail
#     675             log.error("Unable to retrieve routing information")
# --> 676             raise ServiceUnavailable("Unable to retrieve routing information")
#     677
#     678     def update_connection_pool(self, *, database):
#
# ServiceUnavailable: Unable to retrieve routing information
